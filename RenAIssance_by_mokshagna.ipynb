# %% [markdown]
# <a href="https://colab.research.google.com/github/moksha-hub/RenAIssance_OCR/blob/main/RenAIssance_by_mokshagna.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo apt-get -y install tree
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tree is already the newest version (2.0.2-1).
# 0 upgraded, 0 newly installed, 0 to remove and 29 not upgraded.

# %%
import shutil

dataset_dir = "/content/dataset"

# Recursively delete the dataset folder
shutil.rmtree(dataset_dir, ignore_errors=True)

print(f"Removed '{dataset_dir}' and all its contents.")
# Out:
# Removed '/content/dataset' and all its contents.

# %%
#############################################
# 0. (Optional) Mount Google Drive
#############################################
# If you have already mounted your Drive, you can comment out these lines:
from google.colab import drive
drive.mount('/content/drive')

#############################################
# 1. Install Dependencies
#############################################
# !sudo apt-get -y install poppler-utils
# !pip install pdf2image python-docx PyPDF2 opencv-python

#############################################
# 2. Imports and Utility Functions
#############################################
import os
import re
import gc
import cv2
import docx
import numpy as np
from PyPDF2 import PdfReader
from pdf2image import convert_from_path

def read_transcriptions_from_docx(docx_path):
    """
    Reads a .docx file and returns a string containing all paragraphs joined.
    """
    doc = docx.Document(docx_path)
    paragraphs = [p.text for p in doc.paragraphs if p.text.strip()]
    return "\n".join(paragraphs)

def convert_pdf_to_images_single_page(pdf_path, output_folder, dpi=150):
    """
    Converts a large PDF to PNG images one page at a time, reducing memory usage.
    Default dpi=150 to further reduce memory usage. Adjust as needed.
    """
    if not os.path.exists(output_folder):
        os.makedirs(output_folder, exist_ok=True)

    reader = PdfReader(pdf_path)
    total_pages = len(reader.pages)
    print(f"[Single-Page Mode] Processing '{os.path.basename(pdf_path)}' with {total_pages} pages...")

    for page_num in range(1, total_pages + 1):
        pages = convert_from_path(
            pdf_path,
            dpi=dpi,
            first_page=page_num,
            last_page=page_num
        )
        page_image = pages[0]
        out_path = os.path.join(output_folder, f"page_{page_num}.png")
        page_image.save(out_path, "PNG")

        # Free memory for this page
        del page_image
        del pages
        gc.collect()

    print(f"Converted '{os.path.basename(pdf_path)}' into {total_pages} images in '{output_folder}'")

def convert_pdf_to_images_all_at_once(pdf_path, output_folder, dpi=300):
    """
    Converts all pages of a PDF in one pass. Higher DPI=300 for good quality.
    Use this for smaller PDFs to speed up processing.
    """
    if not os.path.exists(output_folder):
        os.makedirs(output_folder, exist_ok=True)

    pages = convert_from_path(pdf_path, dpi=dpi)
    for idx, page in enumerate(pages):
        out_path = os.path.join(output_folder, f"page_{idx+1}.png")
        page.save(out_path, "PNG")

    print(f"Converted '{os.path.basename(pdf_path)}' into {len(pages)} images in '{output_folder}'")

def segment_into_lines(page_image, threshold=10):
    """
    Splits a page image into multiple line images using a simple horizontal projection approach.
    Returns a list of cropped line images.
    threshold=10 means a row must have at least 10 black pixels to be considered text.
    Adjust as needed for your documents.
    """
    gray = cv2.cvtColor(page_image, cv2.COLOR_BGR2GRAY)
    # Otsu binarization
    _, bw = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
    # Sum horizontally. If text is white on black, do: bw = 255 - bw
    horizontal_sum = np.sum(bw == 0, axis=1)

    in_line = False
    start_idx = 0
    line_indices = []

    for i, val in enumerate(horizontal_sum):
        if val > threshold and not in_line:
            in_line = True
            start_idx = i
        elif val <= threshold and in_line:
            in_line = False
            end_idx = i
            line_indices.append((start_idx, end_idx))

    line_images = []
    for (start, end) in line_indices:
        line_img = page_image[start:end, :]  # entire width
        line_images.append(line_img)
    return line_images

#############################################
# 3. Splitting Logic: PDF -> Page Images -> Line Images
#############################################
def split_page_images_into_lines(page_images_folder):
    """
    For each page image in page_images_folder, segment it into lines and store them in a 'lines/' subfolder.
    e.g. page_1.png -> lines/page_1_line_0.png, page_1_line_1.png, ...
    """
    lines_folder = os.path.join(page_images_folder, "lines")
    os.makedirs(lines_folder, exist_ok=True)

    for file_name in sorted(os.listdir(page_images_folder)):
        if file_name.lower().endswith((".png", ".jpg", ".jpeg")) and not file_name.startswith("line_"):
            page_path = os.path.join(page_images_folder, file_name)
            page_img = cv2.imread(page_path, cv2.IMREAD_COLOR)
            if page_img is None:
                continue

            lines = segment_into_lines(page_img, threshold=10)
            base_name = os.path.splitext(file_name)[0]
            for idx, line_img in enumerate(lines):
                line_path = os.path.join(lines_folder, f"{base_name}_line_{idx}.png")
                cv2.imwrite(line_path, line_img)
            print(f"Split '{file_name}' into {len(lines)} lines in '{lines_folder}'")

#############################################
# 4. Main Function to Create a Dataset with Further Splitting
#############################################
def create_dataset_with_line_splitting(
    sources_folder,
    transcriptions_folder,
    local_dataset_dir,
    size_threshold_mb=20,
    single_page_dpi=150,
    all_at_once_dpi=300
):
    """
    1) For each PDF in sources_folder:
       - Create folder in local_dataset_dir with same base name
       - Convert PDF to page images
       - Attempt to match .docx by base name overlap
       - Read docx, save to transcription.txt
       - Then further split each page image into lines in a lines/ subfolder
    """
    import docx

    if not os.path.exists(local_dataset_dir):
        os.makedirs(local_dataset_dir, exist_ok=True)

    docx_files = [f for f in os.listdir(transcriptions_folder) if f.lower().endswith(".docx")]

    def find_best_match_docx(base_name, docx_files):
        base_words = re.findall(r"\w+", base_name.lower())
        best_file = None
        best_score = 0
        for docx_file in docx_files:
            docx_stem = os.path.splitext(docx_file)[0].lower()
            docx_words = re.findall(r"\w+", docx_stem)
            overlap = len(set(base_words).intersection(docx_words))
            if overlap > best_score:
                best_score = overlap
                best_file = docx_file
        return best_file if best_score > 0 else None

    for file_name in os.listdir(sources_folder):
        if file_name.lower().endswith(".pdf"):
            base_name = os.path.splitext(file_name)[0]
            pdf_path = os.path.join(sources_folder, file_name)

            source_folder = os.path.join(local_dataset_dir, base_name)
            images_folder = os.path.join(source_folder, "images")
            os.makedirs(images_folder, exist_ok=True)

            pdf_size = os.path.getsize(pdf_path)
            if pdf_size > size_threshold_mb * 1024 * 1024:
                convert_pdf_to_images_single_page(pdf_path, images_folder, dpi=single_page_dpi)
            else:
                convert_pdf_to_images_all_at_once(pdf_path, images_folder, dpi=all_at_once_dpi)

            # find best matching docx
            matched_docx = find_best_match_docx(base_name, docx_files)
            if matched_docx:
                docx_path = os.path.join(transcriptions_folder, matched_docx)
                doc = docx.Document(docx_path)
                paragraphs = [p.text for p in doc.paragraphs if p.text.strip()]
                transcription_text = "\n".join(paragraphs)

                transcription_out_path = os.path.join(source_folder, "transcription.txt")
                with open(transcription_out_path, "w", encoding="utf-8") as txt_file:
                    txt_file.write(transcription_text)
                print(f"Transcription from '{matched_docx}' saved to '{transcription_out_path}'\n")
            else:
                print(f"No matching Word document found for '{file_name}'.\n")

            # Now further split each page image into lines
            split_page_images_into_lines(images_folder)

    print("\nFinal dataset structure in", local_dataset_dir)
    get_ipython().system(f"tree -L 3 {local_dataset_dir}")

#############################################
# 5. Example Usage
#############################################
sources_folder = "/content/drive/MyDrive/RenAI Printed img/Test sources"
transcriptions_folder = "/content/drive/MyDrive/RenAI Printed img/Test transcriptions"
local_dataset_dir = "/content/dataset_with_lines"

create_dataset_with_line_splitting(
    sources_folder,
    transcriptions_folder,
    local_dataset_dir,
    size_threshold_mb=20,
    single_page_dpi=150,
    all_at_once_dpi=300
)
# Out:
# Mounted at /content/drive
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   poppler-utils
# 0 upgraded, 1 newly installed, 0 to remove and 29 not upgraded.
# Need to get 186 kB of archives.
# After this operation, 696 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 poppler-utils amd64 22.02.0-2ubuntu0.6 [186 kB]
# Fetched 186 kB in 2s (118 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package poppler-utils.
# (Reading database ... 126217 files and directories currently installed.)
# Preparing to unpack .../poppler-utils_22.02.0-2ubuntu0.6_amd64.deb ...
# Unpacking poppler-utils (22.02.0-2ubuntu0.6) ...
# Setting up poppler-utils (22.02.0-2ubuntu0.6) ...
# Processing triggers for man-db (2.10.2-1) ...
# Collecting pdf2image
#   Downloading pdf2image-1.17.0-py3-none-any.whl.metadata (6.2 kB)
# Collecting python-docx
#   Downloading python_docx-1.1.2-py3-none-any.whl.metadata (2.0 kB)
# Collecting PyPDF2
#   Downloading pypdf2-3.0.1-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from pdf2image) (11.1.0)
# Requirement already satisfied: lxml>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from python-docx) (5.3.1)
# Requirement already satisfied: typing-extensions>=4.9.0 in /usr/local/lib/python3.11/dist-packages (from python-docx) (4.12.2)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.11/dist-packages (from opencv-python) (2.0.2)
# Downloading pdf2image-1.17.0-py3-none-any.whl (11 kB)
# Downloading python_docx-1.1.2-py3-none-any.whl (244 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.3/244.3 kB 17.9 MB/s eta 0:00:00
# Downloading pypdf2-3.0.1-py3-none-any.whl (232 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 22.5 MB/s eta 0:00:00
# Installing collected packages: python-docx, PyPDF2, pdf2image
# Successfully installed PyPDF2-3.0.1 pdf2image-1.17.0 python-docx-1.1.2
# [Single-Page Mode] Processing 'PORCONES.228.35 – 1636.pdf' with 16 pages...
# Converted 'PORCONES.228.35 – 1636.pdf' into 16 images in '/content/dataset_with_lines/PORCONES.228.35 – 1636/images'
# Transcription from 'PORCONES.228.35 1636 transcription.docx' saved to '/content/dataset_with_lines/PORCONES.228.35 – 1636/transcription.txt'
#
# Split 'page_1.png' into 15 lines in '/content/dataset_with_lines/PORCONES.228.35 – 1636/images/lines'
# Split 'page_10.png' into 12 lines in '/content/dataset_with_lines/PORCONES.228.35 – 1636/images/lines'
# Split 'page_11.png' into 10 lines in '/content/dataset_with_lines/PORCONES.228.35 – 1636/images/lines'
# Split 'page_12.png' into 0 lines in '/content/dataset_with_lines/PORCONES.228.35 – 1636/images/lines'
# Split 'page_13.png' into 5 lines in '/content/dataset_with_lines/PORCONES.228.35 – 1636/images/lines'
# Split 'page_14.png' into 1 lines in '/content/dataset_with_lines/PORCONES.228.35 – 1636/images/lines'
# Split 'page_15.png' into 10 lines in '/content/dataset_with_lines/PORCONES.228.35 – 1636/images/lines'
# Split 'page_16.png' into 11 lines in '/content/dataset_with_lines/PORCONES.228.35 – 1636/images/lines'
# Split 'page_2.png' into 12 lines in '/content/dataset_with_lines/PORCONES.228.35 – 1636/images/lines'
# Split 'page_3.png' into 12 lines in '/content/dataset_with_lines/PORCONES.228.35 – 1636/images/lines'
# Split 'page_4.png' into 41 lines in '/content/dataset_with_lines/PORCONES.228.35 – 1636/images/lines'
# Split 'page_5.png' into 1 lines in '/content/dataset_with_lines/PORCONES.228.35 – 1636/images/lines'
# Split 'page_6.png' into 13 lines in '/content/dataset_with_lines/PORCONES.228.35 – 1636/images/lines'
# Split 'page_7.png' into 0 lines in '/content/dataset_with_lines/PORCONES.228.35 – 1636/images/lines'
# Split 'page_8.png' into 17 lines in '/content/dataset_with_lines/PORCONES.228.35 – 1636/images/lines'
# Split 'page_9.png' into 3 lines in '/content/dataset_with_lines/PORCONES.228.35 – 1636/images/lines'
# Converted 'Ezcaray - Vozes.pdf' into 11 images in '/content/dataset_with_lines/Ezcaray - Vozes/images'
# Transcription from 'Ezcaray transcription.docx' saved to '/content/dataset_with_lines/Ezcaray - Vozes/transcription.txt'
#
# Split 'page_1.png' into 18 lines in '/content/dataset_with_lines/Ezcaray - Vozes/images/lines'
# Split 'page_10.png' into 24 lines in '/content/dataset_with_lines/Ezcaray - Vozes/images/lines'
# Split 'page_11.png' into 20 lines in '/content/dataset_with_lines/Ezcaray - Vozes/images/lines'
# Split 'page_2.png' into 29 lines in '/content/dataset_with_lines/Ezcaray - Vozes/images/lines'
# Split 'page_3.png' into 10 lines in '/content/dataset_with_lines/Ezcaray - Vozes/images/lines'
# Split 'page_4.png' into 24 lines in '/content/dataset_with_lines/Ezcaray - Vozes/images/lines'
# Split 'page_5.png' into 25 lines in '/content/dataset_with_lines/Ezcaray - Vozes/images/lines'
# Split 'page_6.png' into 25 lines in '/content/dataset_with_lines/Ezcaray - Vozes/images/lines'
# Split 'page_7.png' into 22 lines in '/content/dataset_with_lines/Ezcaray - Vozes/images/lines'
# Split 'page_8.png' into 33 lines in '/content/dataset_with_lines/Ezcaray - Vozes/images/lines'
# Split 'page_9.png' into 19 lines in '/content/dataset_with_lines/Ezcaray - Vozes/images/lines'
# Converted 'Paredes - Reglas generales.pdf' into 9 images in '/content/dataset_with_lines/Paredes - Reglas generales/images'
# Transcription from 'Paredes transcription.docx' saved to '/content/dataset_with_lines/Paredes - Reglas generales/transcription.txt'
#
# Split 'page_1.png' into 14 lines in '/content/dataset_with_lines/Paredes - Reglas generales/images/lines'
# Split 'page_2.png' into 3 lines in '/content/dataset_with_lines/Paredes - Reglas generales/images/lines'
# Split 'page_3.png' into 17 lines in '/content/dataset_with_lines/Paredes - Reglas generales/images/lines'
# Split 'page_4.png' into 0 lines in '/content/dataset_with_lines/Paredes - Reglas generales/images/lines'
# Split 'page_5.png' into 5 lines in '/content/dataset_with_lines/Paredes - Reglas generales/images/lines'
# Split 'page_6.png' into 3 lines in '/content/dataset_with_lines/Paredes - Reglas generales/images/lines'
# Split 'page_7.png' into 0 lines in '/content/dataset_with_lines/Paredes - Reglas generales/images/lines'
# Split 'page_8.png' into 0 lines in '/content/dataset_with_lines/Paredes - Reglas generales/images/lines'
# Split 'page_9.png' into 0 lines in '/content/dataset_with_lines/Paredes - Reglas generales/images/lines'
# Converted 'Mendo - Principe perfecto.pdf' into 9 images in '/content/dataset_with_lines/Mendo - Principe perfecto/images'
# Transcription from 'Mendo transcription.docx' saved to '/content/dataset_with_lines/Mendo - Principe perfecto/transcription.txt'
#
# Split 'page_1.png' into 27 lines in '/content/dataset_with_lines/Mendo - Principe perfecto/images/lines'
# Split 'page_2.png' into 1 lines in '/content/dataset_with_lines/Mendo - Principe perfecto/images/lines'
# Split 'page_3.png' into 29 lines in '/content/dataset_with_lines/Mendo - Principe perfecto/images/lines'
# Split 'page_4.png' into 1 lines in '/content/dataset_with_lines/Mendo - Principe perfecto/images/lines'
# Split 'page_5.png' into 21 lines in '/content/dataset_with_lines/Mendo - Principe perfecto/images/lines'
# Split 'page_6.png' into 1 lines in '/content/dataset_with_lines/Mendo - Principe perfecto/images/lines'
# Split 'page_7.png' into 1 lines in '/content/dataset_with_lines/Mendo - Principe perfecto/images/lines'
# Split 'page_8.png' into 1 lines in '/content/dataset_with_lines/Mendo - Principe perfecto/images/lines'
# Split 'page_9.png' into 1 lines in '/content/dataset_with_lines/Mendo - Principe perfecto/images/lines'
# Converted 'Constituciones sinodales Calahorra 1602.pdf' into 6 images in '/content/dataset_with_lines/Constituciones sinodales Calahorra 1602/images'
# Transcription from 'Constituciones sinodales transcription.docx' saved to '/content/dataset_with_lines/Constituciones sinodales Calahorra 1602/transcription.txt'
#
# Split 'page_1.png' into 0 lines in '/content/dataset_with_lines/Constituciones sinodales Calahorra 1602/images/lines'
# Split 'page_2.png' into 57 lines in '/content/dataset_with_lines/Constituciones sinodales Calahorra 1602/images/lines'
# Split 'page_3.png' into 1 lines in '/content/dataset_with_lines/Constituciones sinodales Calahorra 1602/images/lines'
# Split 'page_4.png' into 1 lines in '/content/dataset_with_lines/Constituciones sinodales Calahorra 1602/images/lines'
# Split 'page_5.png' into 16 lines in '/content/dataset_with_lines/Constituciones sinodales Calahorra 1602/images/lines'
# Split 'page_6.png' into 7 lines in '/content/dataset_with_lines/Constituciones sinodales Calahorra 1602/images/lines'
# Converted 'Buendia - Instruccion.pdf' into 6 images in '/content/dataset_with_lines/Buendia - Instruccion/images'
# Transcription from 'Buendia transcription.docx' saved to '/content/dataset_with_lines/Buendia - Instruccion/transcription.txt'
#
# Split 'page_1.png' into 22 lines in '/content/dataset_with_lines/Buendia - Instruccion/images/lines'
# Split 'page_2.png' into 19 lines in '/content/dataset_with_lines/Buendia - Instruccion/images/lines'
# Split 'page_3.png' into 21 lines in '/content/dataset_with_lines/Buendia - Instruccion/images/lines'
# Split 'page_4.png' into 14 lines in '/content/dataset_with_lines/Buendia - Instruccion/images/lines'
# Split 'page_5.png' into 19 lines in '/content/dataset_with_lines/Buendia - Instruccion/images/lines'
# Split 'page_6.png' into 9 lines in '/content/dataset_with_lines/Buendia - Instruccion/images/lines'
# Converted 'Padilla - 2 Noble perfecto_Extract.pdf' into 16 images in '/content/dataset_with_lines/Padilla - 2 Noble perfecto_Extract/images'
# Transcription from 'Padilla - 2 Noble perfecto_Transcription.docx' saved to '/content/dataset_with_lines/Padilla - 2 Noble perfecto_Extract/transcription.txt'
#
# Split 'page_1.png' into 0 lines in '/content/dataset_with_lines/Padilla - 2 Noble perfecto_Extract/images/lines'
# Split 'page_10.png' into 0 lines in '/content/dataset_with_lines/Padilla - 2 Noble perfecto_Extract/images/lines'
# Split 'page_11.png' into 0 lines in '/content/dataset_with_lines/Padilla - 2 Noble perfecto_Extract/images/lines'
# Split 'page_12.png' into 2 lines in '/content/dataset_with_lines/Padilla - 2 Noble perfecto_Extract/images/lines'
# Split 'page_13.png' into 3 lines in '/content/dataset_with_lines/Padilla - 2 Noble perfecto_Extract/images/lines'
# Split 'page_14.png' into 0 lines in '/content/dataset_with_lines/Padilla - 2 Noble perfecto_Extract/images/lines'
# Split 'page_15.png' into 0 lines in '/content/dataset_with_lines/Padilla - 2 Noble perfecto_Extract/images/lines'
# Split 'page_16.png' into 0 lines in '/content/dataset_with_lines/Padilla - 2 Noble perfecto_Extract/images/lines'
# Split 'page_2.png' into 0 lines in '/content/dataset_with_lines/Padilla - 2 Noble perfecto_Extract/images/lines'
# Split 'page_3.png' into 3 lines in '/content/dataset_with_lines/Padilla - 2 Noble perfecto_Extract/images/lines'
# Split 'page_4.png' into 1 lines in '/content/dataset_with_lines/Padilla - 2 Noble perfecto_Extract/images/lines'
# Split 'page_5.png' into 4 lines in '/content/dataset_with_lines/Padilla - 2 Noble perfecto_Extract/images/lines'
# Split 'page_6.png' into 0 lines in '/content/dataset_with_lines/Padilla - 2 Noble perfecto_Extract/images/lines'
# Split 'page_7.png' into 0 lines in '/content/dataset_with_lines/Padilla - 2 Noble perfecto_Extract/images/lines'
# Split 'page_8.png' into 0 lines in '/content/dataset_with_lines/Padilla - 2 Noble perfecto_Extract/images/lines'
# Split 'page_9.png' into 0 lines in '/content/dataset_with_lines/Padilla - 2 Noble perfecto_Extract/images/lines'
# Converted 'Padilla_Nobleza_virtuosa_testExtract.pdf' into 16 images in '/content/dataset_with_lines/Padilla_Nobleza_virtuosa_testExtract/images'
# No matching Word document found for 'Padilla_Nobleza_virtuosa_testExtract.pdf'.
#
# Split 'page_1.png' into 2 lines in '/content/dataset_with_lines/Padilla_Nobleza_virtuosa_testExtract/images/lines'
# Split 'page_10.png' into 0 lines in '/content/dataset_with_lines/Padilla_Nobleza_virtuosa_testExtract/images/lines'
# Split 'page_11.png' into 0 lines in '/content/dataset_with_lines/Padilla_Nobleza_virtuosa_testExtract/images/lines'
# Split 'page_12.png' into 0 lines in '/content/dataset_with_lines/Padilla_Nobleza_virtuosa_testExtract/images/lines'
# Split 'page_13.png' into 0 lines in '/content/dataset_with_lines/Padilla_Nobleza_virtuosa_testExtract/images/lines'
# Split 'page_14.png' into 2 lines in '/content/dataset_with_lines/Padilla_Nobleza_virtuosa_testExtract/images/lines'
# Split 'page_15.png' into 2 lines in '/content/dataset_with_lines/Padilla_Nobleza_virtuosa_testExtract/images/lines'
# Split 'page_16.png' into 0 lines in '/content/dataset_with_lines/Padilla_Nobleza_virtuosa_testExtract/images/lines'
# Split 'page_2.png' into 0 lines in '/content/dataset_with_lines/Padilla_Nobleza_virtuosa_testExtract/images/lines'
# Split 'page_3.png' into 1 lines in '/content/dataset_with_lines/Padilla_Nobleza_virtuosa_testExtract/images/lines'
# Split 'page_4.png' into 2 lines in '/content/dataset_with_lines/Padilla_Nobleza_virtuosa_testExtract/images/lines'
# Split 'page_5.png' into 0 lines in '/content/dataset_with_lines/Padilla_Nobleza_virtuosa_testExtract/images/lines'
# Split 'page_6.png' into 3 lines in '/content/dataset_with_lines/Padilla_Nobleza_virtuosa_testExtract/images/lines'
# Split 'page_7.png' into 0 lines in '/content/dataset_with_lines/Padilla_Nobleza_virtuosa_testExtract/images/lines'
# Split 'page_8.png' into 2 lines in '/content/dataset_with_lines/Padilla_Nobleza_virtuosa_testExtract/images/lines'
# Split 'page_9.png' into 2 lines in '/content/dataset_with_lines/Padilla_Nobleza_virtuosa_testExtract/images/lines'
#
# Final dataset structure in /content/dataset_with_lines
# /content/dataset_with_lines
# ├── Buendia - Instruccion
# │   ├── images
# │   │   ├── lines
# │   │   ├── page_1.png
# │   │   ├── page_2.png
# │   │   ├── page_3.png
# │   │   ├── page_4.png
# │   │   ├── page_5.png
# │   │   └── page_6.png
# │   └── transcription.txt
# ├── Constituciones sinodales Calahorra 1602
# │   ├── images
# │   │   ├── lines
# │   │   ├── page_1.png
# │   │   ├── page_2.png
# │   │   ├── page_3.png
# │   │   ├── page_4.png
# │   │   ├── page_5.png
# │   │   └── page_6.png
# │   └── transcription.txt
# ├── Ezcaray - Vozes
# │   ├── images
# │   │   ├── lines
# │   │   ├── page_10.png
# │   │   ├── page_11.png
# │   │   ├── page_1.png
# │   │   ├── page_2.png
# │   │   ├── page_3.png
# │   │   ├── page_4.png
# │   │   ├── page_5.png
# │   │   ├── page_6.png
# │   │   ├── page_7.png
# │   │   ├── page_8.png
# │   │   └── page_9.png
# │   └── transcription.txt
# ├── Mendo - Principe perfecto
# │   ├── images
# │   │   ├── lines
# │   │   ├── page_1.png
# │   │   ├── page_2.png
# │   │   ├── page_3.png
# │   │   ├── page_4.png
# │   │   ├── page_5.png
# │   │   ├── page_6.png
# │   │   ├── page_7.png
# │   │   ├── page_8.png
# │   │   └── page_9.png
# │   └── transcription.txt
# ├── Padilla - 2 Noble perfecto_Extract
# │   ├── images
# │   │   ├── lines
# │   │   ├── page_10.png
# │   │   ├── page_11.png
# │   │   ├── page_12.png
# │   │   ├── page_13.png
# │   │   ├── page_14.png
# │   │   ├── page_15.png
# │   │   ├── page_16.png
# │   │   ├── page_1.png
# │   │   ├── page_2.png
# │   │   ├── page_3.png
# │   │   ├── page_4.png
# │   │   ├── page_5.png
# │   │   ├── page_6.png
# │   │   ├── page_7.png
# │   │   ├── page_8.png
# │   │   └── page_9.png
# │   └── transcription.txt
# ├── Padilla_Nobleza_virtuosa_testExtract
# │   └── images
# │       ├── lines
# │       ├── page_10.png
# │       ├── page_11.png
# │       ├── page_12.png
# │       ├── page_13.png
# │       ├── page_14.png
# │       ├── page_15.png
# │       ├── page_16.png
# │       ├── page_1.png
# │       ├── page_2.png
# │       ├── page_3.png
# │       ├── page_4.png
# │       ├── page_5.png
# │       ├── page_6.png
# │       ├── page_7.png
# │       ├── page_8.png
# │       └── page_9.png
# ├── Paredes - Reglas generales
# │   ├── images
# │   │   ├── lines
# │   │   ├── page_1.png
# │   │   ├── page_2.png
# │   │   ├── page_3.png
# │   │   ├── page_4.png
# │   │   ├── page_5.png
# │   │   ├── page_6.png
# │   │   ├── page_7.png
# │   │   ├── page_8.png
# │   │   └── page_9.png
# │   └── transcription.txt
# └── PORCONES.228.35 – 1636
#     ├── images
#     │   ├── lines
#     │   ├── page_10.png
#     │   ├── page_11.png
#     │   ├── page_12.png
#     │   ├── page_13.png
#     │   ├── page_14.png
#     │   ├── page_15.png
#     │   ├── page_16.png
#     │   ├── page_1.png
#     │   ├── page_2.png
#     │   ├── page_3.png
#     │   ├── page_4.png
#     │   ├── page_5.png
#     │   ├── page_6.png
#     │   ├── page_7.png
#     │   ├── page_8.png
#     │   └── page_9.png
#     └── transcription.txt
#
# 24 directories, 96 files

# %%
# !pip install paddlepaddle-gpu -f https://www.paddlepaddle.org.cn/whl/mkl/avx/stable.html
# Out:
# Looking in links: https://www.paddlepaddle.org.cn/whl/mkl/avx/stable.html
# Collecting paddlepaddle-gpu
#   Downloading paddlepaddle_gpu-2.6.2-cp311-cp311-manylinux1_x86_64.whl.metadata (8.6 kB)
# Requirement already satisfied: httpx in /usr/local/lib/python3.11/dist-packages (from paddlepaddle-gpu) (0.28.1)
# Requirement already satisfied: numpy>=1.13 in /usr/local/lib/python3.11/dist-packages (from paddlepaddle-gpu) (2.0.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from paddlepaddle-gpu) (11.1.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from paddlepaddle-gpu) (4.4.2)
# Collecting astor (from paddlepaddle-gpu)
#   Downloading astor-0.8.1-py2.py3-none-any.whl.metadata (4.2 kB)
# Collecting opt-einsum==3.3.0 (from paddlepaddle-gpu)
#   Downloading opt_einsum-3.3.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: protobuf>=3.20.2 in /usr/local/lib/python3.11/dist-packages (from paddlepaddle-gpu) (5.29.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx->paddlepaddle-gpu) (4.9.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx->paddlepaddle-gpu) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx->paddlepaddle-gpu) (1.0.7)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from httpx->paddlepaddle-gpu) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx->paddlepaddle-gpu) (0.14.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx->paddlepaddle-gpu) (1.3.1)
# Requirement already satisfied: typing_extensions>=4.5 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx->paddlepaddle-gpu) (4.12.2)
# Downloading paddlepaddle_gpu-2.6.2-cp311-cp311-manylinux1_x86_64.whl (759.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 759.0/759.0 MB 1.8 MB/s eta 0:00:00
# Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 5.4 MB/s eta 0:00:00
# Downloading astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Installing collected packages: opt-einsum, astor, paddlepaddle-gpu
#   Attempting uninstall: opt-einsum
#     Found existing installation: opt_einsum 3.4.0
#     Uninstalling opt_einsum-3.4.0:
#       Successfully uninstalled opt_einsum-3.4.0
# Successfully installed astor-0.8.1 opt-einsum-3.3.0 paddlepaddle-gpu-2.6.2

# %%
#############################################
# 0. (Optional) Mount Google Drive
#############################################
from google.colab import drive
drive.mount('/content/drive')

#############################################
# 1. Install Dependencies
#############################################
# !sudo apt-get -y install poppler-utils
# !pip install pdf2image python-docx PyPDF2 opencv-python rapidfuzz paddleocr

#############################################
# 2. Imports and Utility Functions
#############################################
import os
import re
import gc
import cv2
import docx
import numpy as np
from PyPDF2 import PdfReader
from pdf2image import convert_from_path
from paddleocr import PaddleOCR
from rapidfuzz import fuzz

def read_transcriptions_from_txt(txt_path):
    with open(txt_path, "r", encoding="utf-8") as f:
        return [line.strip() for line in f if line.strip()]

def partial_ocr_line(line_image_path, ocr_engine):
    """
    Run PaddleOCR on a single line image, return recognized text (best guess).
    """
    result = ocr_engine.ocr(line_image_path, rec=True)
    if result and len(result[0]) > 0:
        # result[0][0] => bounding box, result[0][1] => (text, confidence)
        # But for a single line, there's typically 1 bounding box.
        recognized_text = result[0][0][1][0]
    else:
        recognized_text = ""
    return recognized_text

def find_best_line_match(recognized_text, doc_lines):
    """
    Fuzzy match recognized_text to each line in doc_lines, return best line and best score.
    """
    best_score = -1
    best_line = None
    for candidate_line in doc_lines:
        score = fuzz.ratio(recognized_text.lower(), candidate_line.lower())
        if score > best_score:
            best_score = score
            best_line = candidate_line
    return best_line, best_score

def generate_line_level_texts(
    dataset_root,
    paddle_ocr_lang="en"
):
    """
    1) For each <PDF_Name>/images/lines folder in dataset_root,
       read line images (page_1_line_0.png, etc.).
    2) Load the entire transcription.txt from <PDF_Name>/transcription.txt as doc_lines (split by lines).
    3) For each line image, run partial OCR, fuzzy match to doc_lines, and create .txt file.
    """
    ocr_engine = PaddleOCR(lang=paddle_ocr_lang, rec=True, det=False, use_angle_cls=False)

    for folder_name in sorted(os.listdir(dataset_root)):
        folder_path = os.path.join(dataset_root, folder_name)
        if not os.path.isdir(folder_path):
            continue

        # e.g. /content/dataset_with_lines/Mendo - Principe perfecto
        transcription_file = os.path.join(folder_path, "transcription.txt")
        images_folder = os.path.join(folder_path, "images")
        lines_folder = os.path.join(images_folder, "lines")

        if not os.path.exists(transcription_file):
            print(f"No transcription.txt in {folder_name}, skipping.")
            continue
        if not os.path.exists(lines_folder):
            print(f"No lines folder in {folder_name}, skipping.")
            continue

        doc_lines = read_transcriptions_from_txt(transcription_file)
        print(f"\n[{folder_name}] Found {len(doc_lines)} lines in transcription.txt")

        # For each line image in lines_folder, do partial OCR + fuzzy match
        for file_name in sorted(os.listdir(lines_folder)):
            if file_name.lower().endswith((".png", ".jpg", ".jpeg")) and not file_name.endswith(".txt"):
                line_img_path = os.path.join(lines_folder, file_name)
                recognized_text = partial_ocr_line(line_img_path, ocr_engine)

                if recognized_text.strip():
                    best_line, best_score = find_best_line_match(recognized_text, doc_lines)
                else:
                    best_line, best_score = "[NO RECOGNIZED TEXT]", 0

                # Save best_line to .txt
                txt_name = file_name.rsplit(".", 1)[0] + ".txt"
                txt_path = os.path.join(lines_folder, txt_name)
                with open(txt_path, "w", encoding="utf-8") as f:
                    f.write(best_line)

                print(f"  -> {file_name} recognized='{recognized_text[:30]}...' matched='{best_line[:30]}...' score={best_score}")
    print("\nLine-level .txt generation complete.")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# poppler-utils is already the newest version (22.02.0-2ubuntu0.6).
# 0 upgraded, 0 newly installed, 0 to remove and 29 not upgraded.
# Requirement already satisfied: pdf2image in /usr/local/lib/python3.11/dist-packages (1.17.0)
# Requirement already satisfied: python-docx in /usr/local/lib/python3.11/dist-packages (1.1.2)
# Requirement already satisfied: PyPDF2 in /usr/local/lib/python3.11/dist-packages (3.0.1)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Collecting rapidfuzz
#   Downloading rapidfuzz-3.12.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting paddleocr
#   Downloading paddleocr-2.10.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from pdf2image) (11.1.0)
# Requirement already satisfied: lxml>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from python-docx) (5.3.1)
# Requirement already satisfied: typing-extensions>=4.9.0 in /usr/local/lib/python3.11/dist-packages (from python-docx) (4.12.2)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.11/dist-packages (from opencv-python) (2.0.2)
# Requirement already satisfied: shapely in /usr/local/lib/python3.11/dist-packages (from paddleocr) (2.0.7)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.11/dist-packages (from paddleocr) (0.25.2)
# Collecting pyclipper (from paddleocr)
#   Downloading pyclipper-1.3.0.post6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.0 kB)
# Collecting lmdb (from paddleocr)
#   Downloading lmdb-1.6.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.1 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from paddleocr) (4.67.1)
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.11/dist-packages (from paddleocr) (4.11.0.86)
# Requirement already satisfied: cython in /usr/local/lib/python3.11/dist-packages (from paddleocr) (3.0.12)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from paddleocr) (6.0.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from paddleocr) (4.13.3)
# Requirement already satisfied: fonttools>=4.24.0 in /usr/local/lib/python3.11/dist-packages (from paddleocr) (4.56.0)
# Collecting fire>=0.3.0 (from paddleocr)
#   Downloading fire-0.7.0.tar.gz (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 4.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from paddleocr) (2.32.3)
# Requirement already satisfied: albumentations in /usr/local/lib/python3.11/dist-packages (from paddleocr) (2.0.5)
# Requirement already satisfied: albucore in /usr/local/lib/python3.11/dist-packages (from paddleocr) (0.0.23)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.11/dist-packages (from fire>=0.3.0->paddleocr) (2.5.0)
# Requirement already satisfied: stringzilla>=3.10.4 in /usr/local/lib/python3.11/dist-packages (from albucore->paddleocr) (3.12.3)
# Requirement already satisfied: simsimd>=5.9.2 in /usr/local/lib/python3.11/dist-packages (from albucore->paddleocr) (6.2.1)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in /usr/local/lib/python3.11/dist-packages (from albucore->paddleocr) (4.11.0.86)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.11/dist-packages (from albumentations->paddleocr) (1.14.1)
# Requirement already satisfied: pydantic>=2.9.2 in /usr/local/lib/python3.11/dist-packages (from albumentations->paddleocr) (2.10.6)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->paddleocr) (2.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->paddleocr) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->paddleocr) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->paddleocr) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->paddleocr) (2025.1.31)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.11/dist-packages (from scikit-image->paddleocr) (3.4.2)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.11/dist-packages (from scikit-image->paddleocr) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.11/dist-packages (from scikit-image->paddleocr) (2025.3.13)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.11/dist-packages (from scikit-image->paddleocr) (24.2)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image->paddleocr) (0.4)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.9.2->albumentations->paddleocr) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.9.2->albumentations->paddleocr) (2.27.2)
# Downloading rapidfuzz-3.12.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 37.3 MB/s eta 0:00:00
# Downloading paddleocr-2.10.0-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 35.6 MB/s eta 0:00:00
# Downloading lmdb-1.6.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (297 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.8/297.8 kB 20.2 MB/s eta 0:00:00
# Downloading pyclipper-1.3.0.post6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (969 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 969.6/969.6 kB 31.6 MB/s eta 0:00:00
# Building wheels for collected packages: fire
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.7.0-py3-none-any.whl size=114249 sha256=8668e4d6265e2150c119514c24734f84f23aeefdab208b2f1e2060e1d5c5186f
#   Stored in directory: /root/.cache/pip/wheels/46/54/24/1624fd5b8674eb1188623f7e8e17cdf7c0f6c24b609dfb8a89
# Successfully built fire
# Installing collected packages: pyclipper, lmdb, rapidfuzz, fire, paddleocr
# Successfully installed fire-0.7.0 lmdb-1.6.2 paddleocr-2.10.0 pyclipper-1.3.0.post6 rapidfuzz-3.12.2

# %%
def partial_ocr_line(line_image_path, ocr_engine):
    """
    Run PaddleOCR on a single line image, return recognized text (best guess).
    Safely handles None or empty results.
    """
    result = ocr_engine.ocr(line_image_path, rec=True)

    # If result is None or empty, return empty string
    if not result or len(result) == 0:
        return ""

    # result is typically a list of lists, e.g. [ [ [box], [text, confidence] ], ... ]
    # So we check if result[0] is valid
    if not result[0] or len(result[0]) == 0:
        return ""

    # Finally, parse recognized text from result
    # Usually: result[0][0] => [ [box coords], [text, confidence] ]
    recognized_text = result[0][0][1][0]
    return recognized_text

# %%
ocr_engine = PaddleOCR(lang="es", rec=True, det=False, use_angle_cls=False)
line_img_path = "/content/dataset_with_lines/Mendo - Principe perfecto/images/lines/page_2_line_0.png"
recognized_text = partial_ocr_line(line_img_path, ocr_engine)
print("Recognized text:", recognized_text)
# Out:
# download https://paddleocr.bj.bcebos.com/PP-OCRv3/english/en_PP-OCRv3_det_infer.tar to /root/.paddleocr/whl/det/en/en_PP-OCRv3_det_infer/en_PP-OCRv3_det_infer.tar
# 100%|██████████| 3910/3910 [00:00<00:00, 4995.99it/s]
# download https://paddleocr.bj.bcebos.com/PP-OCRv3/multilingual/latin_PP-OCRv3_rec_infer.tar to /root/.paddleocr/whl/rec/latin/latin_PP-OCRv3_rec_infer/latin_PP-OCRv3_rec_infer.tar
# 100%|██████████| 9930/9930 [00:00<00:00, 10647.21it/s]
# download https://paddleocr.bj.bcebos.com/dygraph_v2.0/ch/ch_ppocr_mobile_v2.0_cls_infer.tar to /root/.paddleocr/whl/cls/ch_ppocr_mobile_v2.0_cls_infer/ch_ppocr_mobile_v2.0_cls_infer.tar
# 100%|██████████| 2138/2138 [00:00<00:00, 3040.87it/s]
# [2025/03/23 08:40:31] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=True, use_xpu=False, use_npu=False, use_mlu=False, use_gcu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='/root/.paddleocr/whl/det/en/en_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='/root/.paddleocr/whl/rec/latin/latin_PP-OCRv3_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='/usr/local/lib/python3.11/dist-packages/paddleocr/ppocr/utils/dict/latin_dict.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=False, cls_model_dir='/root/.paddleocr/whl/cls/ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, onnx_providers=False, onnx_sess_options=False, return_word_box=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, formula_algorithm='LaTeXOCR', formula_model_dir=None, formula_char_dict_path=None, formula_batch_num=1, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, formula=False, ocr=True, recovery=False, recovery_to_markdown=False, use_pdf2docx_api=False, invert=False, binarize=False, alphacolor=(255, 255, 255), lang='es', det=False, rec=True, type='ocr', savefile=False, ocr_version='PP-OCRv4', structure_version='PP-StructureV2')
# [2025/03/23 08:40:31] ppocr WARNING: The first GPU is used for inference by default, GPU ID: 0
# [2025/03/23 08:40:33] ppocr WARNING: The first GPU is used for inference by default, GPU ID: 0
# [2025/03/23 08:40:36] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:37] ppocr DEBUG: dt_boxes num : 19, elapsed : 1.26682710647583
# [2025/03/23 08:40:38] ppocr DEBUG: rec_res num  : 19, elapsed : 0.2907557487487793
# Recognized text: geado el ferlo : logrando dignamente en nueftro Monarcha la gracia

# %%
def partial_ocr_line(line_image_path, ocr_engine):
    result = ocr_engine.ocr(line_image_path, rec=True)
    if not result or len(result) == 0:
        print(f"WARNING: No OCR result for {line_image_path}")
        return ""
    if not result[0] or len(result[0]) == 0:
        print(f"WARNING: No bounding boxes recognized for {line_image_path}")
        return ""

    recognized_text = result[0][0][1][0]
    return recognized_text

# %%
dataset_root = "/content/dataset_with_lines"  # or your dataset path
generate_line_level_texts(dataset_root, paddle_ocr_lang="es")
# Out:
# [2025/03/23 08:40:38] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=True, use_xpu=False, use_npu=False, use_mlu=False, use_gcu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='/root/.paddleocr/whl/det/en/en_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='/root/.paddleocr/whl/rec/latin/latin_PP-OCRv3_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='/usr/local/lib/python3.11/dist-packages/paddleocr/ppocr/utils/dict/latin_dict.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=False, cls_model_dir='/root/.paddleocr/whl/cls/ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, onnx_providers=False, onnx_sess_options=False, return_word_box=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, formula_algorithm='LaTeXOCR', formula_model_dir=None, formula_char_dict_path=None, formula_batch_num=1, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, formula=False, ocr=True, recovery=False, recovery_to_markdown=False, use_pdf2docx_api=False, invert=False, binarize=False, alphacolor=(255, 255, 255), lang='es', det=False, rec=True, type='ocr', savefile=False, ocr_version='PP-OCRv4', structure_version='PP-StructureV2')
# [2025/03/23 08:40:38] ppocr WARNING: The first GPU is used for inference by default, GPU ID: 0
# [2025/03/23 08:40:39] ppocr WARNING: The first GPU is used for inference by default, GPU ID: 0
#
# [Buendia - Instruccion] Found 115 lines in transcription.txt
# [2025/03/23 08:40:41] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:41] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.10181093215942383
# [2025/03/23 08:40:41] ppocr DEBUG: rec_res num  : 2, elapsed : 0.0507512092590332
#   -> page_1_line_0.png recognized='Exit lnstruccion ae cnristiana...' matched='truccion de Christiana, y Poli...' score=54.42176870748299
# [2025/03/23 08:40:41] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:41] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.016129732131958008
# [2025/03/23 08:40:41] ppocr DEBUG: rec_res num  : 0, elapsed : 1.1920928955078125e-06
# WARNING: No bounding boxes recognized for /content/dataset_with_lines/Buendia - Instruccion/images/lines/page_1_line_1.png
#   -> page_1_line_1.png recognized='...' matched='[NO RECOGNIZED TEXT]...' score=0
# [2025/03/23 08:40:41] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:41] ppocr DEBUG: dt_boxes num : 7, elapsed : 0.05198359489440918
# [2025/03/23 08:40:41] ppocr DEBUG: rec_res num  : 7, elapsed : 0.058908939361572266
#   -> page_1_line_10.png recognized='que ella tambien fe dirige a l...' matched='que ella también se dirige a l...' score=94.28571428571428
# [2025/03/23 08:40:41] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:42] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.017185211181640625
# [2025/03/23 08:40:42] ppocr DEBUG: rec_res num  : 1, elapsed : 0.02487039566040039
#   -> page_1_line_11.png recognized='.o es mucho mas. En Vos, (Divi...' matched='lo es mucho mas. En Vos, (Divi...' score=96.7741935483871
# [2025/03/23 08:40:42] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:42] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.01705145835876465
# [2025/03/23 08:40:42] ppocr DEBUG: rec_res num  : 2, elapsed : 0.023412227630615234
#   -> page_1_line_12.png recognized='no Exemplar de todas las virtu...' matched='no Exemplar de todas las virtu...' score=98.36065573770492
# [2025/03/23 08:40:42] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:42] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.02220773696899414
# [2025/03/23 08:40:42] ppocr DEBUG: rec_res num  : 0, elapsed : 1.1920928955078125e-06
# WARNING: No bounding boxes recognized for /content/dataset_with_lines/Buendia - Instruccion/images/lines/page_1_line_13.png
#   -> page_1_line_13.png recognized='...' matched='[NO RECOGNIZED TEXT]...' score=0
# [2025/03/23 08:40:42] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:42] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.017667293548583984
# [2025/03/23 08:40:42] ppocr DEBUG: rec_res num  : 3, elapsed : 0.02270674705505371
#   -> page_1_line_14.png recognized='guro....' matched='gel, y Barcelona, Oc....' score=30.76923076923077
# [2025/03/23 08:40:42] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:42] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.014095067977905273
# [2025/03/23 08:40:42] ppocr DEBUG: rec_res num  : 0, elapsed : 1.430511474609375e-06
# WARNING: No bounding boxes recognized for /content/dataset_with_lines/Buendia - Instruccion/images/lines/page_1_line_15.png
#   -> page_1_line_15.png recognized='...' matched='[NO RECOGNIZED TEXT]...' score=0
# [2025/03/23 08:40:42] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:42] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.014142513275146484
# [2025/03/23 08:40:42] ppocr DEBUG: rec_res num  : 0, elapsed : 1.1920928955078125e-06
# WARNING: No bounding boxes recognized for /content/dataset_with_lines/Buendia - Instruccion/images/lines/page_1_line_16.png
#   -> page_1_line_16.png recognized='...' matched='[NO RECOGNIZED TEXT]...' score=0
# [2025/03/23 08:40:42] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:42] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.012917041778564453
# [2025/03/23 08:40:42] ppocr DEBUG: rec_res num  : 0, elapsed : 9.5367431640625e-07
# WARNING: No bounding boxes recognized for /content/dataset_with_lines/Buendia - Instruccion/images/lines/page_1_line_17.png
#   -> page_1_line_17.png recognized='...' matched='[NO RECOGNIZED TEXT]...' score=0
# [2025/03/23 08:40:42] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:42] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.019766569137573242
# [2025/03/23 08:40:42] ppocr DEBUG: rec_res num  : 0, elapsed : 9.5367431640625e-07
# WARNING: No bounding boxes recognized for /content/dataset_with_lines/Buendia - Instruccion/images/lines/page_1_line_18.png
#   -> page_1_line_18.png recognized='...' matched='[NO RECOGNIZED TEXT]...' score=0
# [2025/03/23 08:40:42] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:42] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.01608109474182129
# [2025/03/23 08:40:42] ppocr DEBUG: rec_res num  : 0, elapsed : 1.1920928955078125e-06
# WARNING: No bounding boxes recognized for /content/dataset_with_lines/Buendia - Instruccion/images/lines/page_1_line_19.png
#   -> page_1_line_19.png recognized='...' matched='[NO RECOGNIZED TEXT]...' score=0
# [2025/03/23 08:40:42] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:42] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.08744978904724121
# [2025/03/23 08:40:42] ppocr DEBUG: rec_res num  : 1, elapsed : 0.05229353904724121
#   -> page_1_line_2.png recognized='X x X...' matched='PDF p1...' score=18.181818181818176
# [2025/03/23 08:40:42] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:42] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.03330564498901367
# [2025/03/23 08:40:42] ppocr DEBUG: rec_res num  : 0, elapsed : 1.6689300537109375e-06
# WARNING: No bounding boxes recognized for /content/dataset_with_lines/Buendia - Instruccion/images/lines/page_1_line_20.png
#   -> page_1_line_20.png recognized='...' matched='[NO RECOGNIZED TEXT]...' score=0
# [2025/03/23 08:40:42] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:42] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.01946711540222168
# [2025/03/23 08:40:42] ppocr DEBUG: rec_res num  : 0, elapsed : 1.430511474609375e-06
# WARNING: No bounding boxes recognized for /content/dataset_with_lines/Buendia - Instruccion/images/lines/page_1_line_21.png
#   -> page_1_line_21.png recognized='...' matched='[NO RECOGNIZED TEXT]...' score=0
# [2025/03/23 08:40:42] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:43] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.019913434982299805
# [2025/03/23 08:40:43] ppocr DEBUG: rec_res num  : 3, elapsed : 0.02515578269958496
#   -> page_1_line_3.png recognized=''AMABLE...' matched='Al...' score=44.44444444444444
# [2025/03/23 08:40:43] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:43] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.015195369720458984
# [2025/03/23 08:40:43] ppocr DEBUG: rec_res num  : 0, elapsed : 1.430511474609375e-06
# WARNING: No bounding boxes recognized for /content/dataset_with_lines/Buendia - Instruccion/images/lines/page_1_line_4.png
#   -> page_1_line_4.png recognized='...' matched='[NO RECOGNIZED TEXT]...' score=0
# [2025/03/23 08:40:43] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:43] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.013845682144165039
# [2025/03/23 08:40:43] ppocr DEBUG: rec_res num  : 0, elapsed : 1.430511474609375e-06
# WARNING: No bounding boxes recognized for /content/dataset_with_lines/Buendia - Instruccion/images/lines/page_1_line_5.png
#   -> page_1_line_5.png recognized='...' matched='[NO RECOGNIZED TEXT]...' score=0
# [2025/03/23 08:40:43] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:43] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.014017820358276367
# [2025/03/23 08:40:43] ppocr DEBUG: rec_res num  : 0, elapsed : 1.1920928955078125e-06
# WARNING: No bounding boxes recognized for /content/dataset_with_lines/Buendia - Instruccion/images/lines/page_1_line_6.png
#   -> page_1_line_6.png recognized='...' matched='[NO RECOGNIZED TEXT]...' score=0
# [2025/03/23 08:40:43] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:43] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.024599075317382812
# [2025/03/23 08:40:43] ppocr DEBUG: rec_res num  : 4, elapsed : 0.025835514068603516
#   -> page_1_line_7.png recognized='Vos , Dulcifsimo Nino...' matched='A Vos, Dulcissimo Niño...' score=83.72093023255813
# [2025/03/23 08:40:43] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:43] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.01646900177001953
# [2025/03/23 08:40:43] ppocr DEBUG: rec_res num  : 1, elapsed : 0.021390914916992188
#   -> page_1_line_8.png recognized='tir como Nino entre los Doctor...' matched='tir como Niño entre los Doctor...' score=93.93939393939394
# [2025/03/23 08:40:43] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:43] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.025835752487182617
# [2025/03/23 08:40:43] ppocr DEBUG: rec_res num  : 2, elapsed : 0.021923065185546875
#   -> page_1_line_9.png recognized='fe confagra humilde efta peque...' matched='se consagra humilde esta peque...' score=87.5
# [2025/03/23 08:40:43] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:43] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.05721139907836914
# [2025/03/23 08:40:43] ppocr DEBUG: rec_res num  : 2, elapsed : 0.04511380195617676
#   -> page_2_line_0.png recognized='Exit lnstruccion ae cnristiana...' matched='truccion de Christiana, y Poli...' score=54.42176870748299
# [2025/03/23 08:40:43] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:44] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.022650718688964844
# [2025/03/23 08:40:44] ppocr DEBUG: rec_res num  : 0, elapsed : 1.6689300537109375e-06
# WARNING: No bounding boxes recognized for /content/dataset_with_lines/Buendia - Instruccion/images/lines/page_2_line_1.png
#   -> page_2_line_1.png recognized='...' matched='[NO RECOGNIZED TEXT]...' score=0
# [2025/03/23 08:40:44] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:44] ppocr DEBUG: dt_boxes num : 9, elapsed : 0.03215336799621582
# [2025/03/23 08:40:44] ppocr DEBUG: rec_res num  : 9, elapsed : 0.03279924392700195
#   -> page_2_line_10.png recognized='Vos...' matched='NIÑO JESUS....' score=28.57142857142857
# [2025/03/23 08:40:44] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:44] ppocr DEBUG: dt_boxes num : 20, elapsed : 0.038305044174194336
# [2025/03/23 08:40:45] ppocr DEBUG: rec_res num  : 20, elapsed : 0.11899447441101074
#   -> page_2_line_11.png recognized='tos ; que no entra vueftra Sab...' matched='tos; que no entra vuestra Sabi...' score=95.23809523809523
# [2025/03/23 08:40:45] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:45] ppocr DEBUG: dt_boxes num : 10, elapsed : 0.029849529266357422
# [2025/03/23 08:40:45] ppocr DEBUG: rec_res num  : 10, elapsed : 0.04964399337768555
#   -> page_2_line_12.png recognized=' mildad. Vueftro amor parece q...' matched='mildad. Vuestro amor parece qu...' score=95.23809523809523
# [2025/03/23 08:40:45] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:45] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.01795816421508789
# [2025/03/23 08:40:45] ppocr DEBUG: rec_res num  : 0, elapsed : 1.1920928955078125e-06
# WARNING: No bounding boxes recognized for /content/dataset_with_lines/Buendia - Instruccion/images/lines/page_2_line_13.png
#   -> page_2_line_13.png recognized='...' matched='[NO RECOGNIZED TEXT]...' score=0
# [2025/03/23 08:40:45] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:45] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.06424760818481445
# [2025/03/23 08:40:45] ppocr DEBUG: rec_res num  : 0, elapsed : 1.6689300537109375e-06
# WARNING: No bounding boxes recognized for /content/dataset_with_lines/Buendia - Instruccion/images/lines/page_2_line_14.png
#   -> page_2_line_14.png recognized='...' matched='[NO RECOGNIZED TEXT]...' score=0
# [2025/03/23 08:40:45] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:45] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.016684770584106445
# [2025/03/23 08:40:46] ppocr DEBUG: rec_res num  : 2, elapsed : 0.054509878158569336
#   -> page_2_line_15.png recognized='crian:...' matched='yor gloria. Amen....' score=34.78260869565217
# [2025/03/23 08:40:46] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:46] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.021286487579345703
# [2025/03/23 08:40:46] ppocr DEBUG: rec_res num  : 0, elapsed : 1.1920928955078125e-06
# WARNING: No bounding boxes recognized for /content/dataset_with_lines/Buendia - Instruccion/images/lines/page_2_line_16.png
#   -> page_2_line_16.png recognized='...' matched='[NO RECOGNIZED TEXT]...' score=0
# [2025/03/23 08:40:46] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:46] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.025242090225219727
# [2025/03/23 08:40:46] ppocr DEBUG: rec_res num  : 0, elapsed : 1.6689300537109375e-06
# WARNING: No bounding boxes recognized for /content/dataset_with_lines/Buendia - Instruccion/images/lines/page_2_line_17.png
#   -> page_2_line_17.png recognized='...' matched='[NO RECOGNIZED TEXT]...' score=0
# [2025/03/23 08:40:46] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:46] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.017599821090698242
# [2025/03/23 08:40:46] ppocr DEBUG: rec_res num  : 1, elapsed : 0.04669308662414551
#   -> page_2_line_18.png recognized='About this bookFREE...' matched='lo que deben estudiar. Por est...' score=37.03703703703704
# [2025/03/23 08:40:46] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:46] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.03878068923950195
# [2025/03/23 08:40:46] ppocr DEBUG: rec_res num  : 0, elapsed : 1.6689300537109375e-06
# WARNING: No bounding boxes recognized for /content/dataset_with_lines/Buendia - Instruccion/images/lines/page_2_line_2.png
#   -> page_2_line_2.png recognized='...' matched='[NO RECOGNIZED TEXT]...' score=0
# [2025/03/23 08:40:46] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:46] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.04363584518432617
# [2025/03/23 08:40:46] ppocr DEBUG: rec_res num  : 0, elapsed : 2.1457672119140625e-06
# WARNING: No bounding boxes recognized for /content/dataset_with_lines/Buendia - Instruccion/images/lines/page_2_line_3.png
#   -> page_2_line_3.png recognized='...' matched='[NO RECOGNIZED TEXT]...' score=0
# [2025/03/23 08:40:46] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:46] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.03335857391357422
# [2025/03/23 08:40:46] ppocr DEBUG: rec_res num  : 0, elapsed : 1.1920928955078125e-06
# WARNING: No bounding boxes recognized for /content/dataset_with_lines/Buendia - Instruccion/images/lines/page_2_line_4.png
#   -> page_2_line_4.png recognized='...' matched='[NO RECOGNIZED TEXT]...' score=0
# [2025/03/23 08:40:46] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:46] ppocr DEBUG: dt_boxes num : 8, elapsed : 0.08870291709899902
# [2025/03/23 08:40:47] ppocr DEBUG: rec_res num  : 8, elapsed : 0.18343353271484375
#   -> page_2_line_5.png recognized='guro diffeno de fu edad : la R...' matched='guro disseño de su edad: la Re...' score=86.56716417910448
# [2025/03/23 08:40:47] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:47] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.052994728088378906
# [2025/03/23 08:40:47] ppocr DEBUG: rec_res num  : 5, elapsed : 0.0866086483001709
#   -> page_2_line_6.png recognized='mas rendida; y la modeftia, y ...' matched='mas rendida; y la modestia, y ...' score=96.96969696969697
# [2025/03/23 08:40:47] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:48] ppocr DEBUG: dt_boxes num : 8, elapsed : 0.04952597618103027
# [2025/03/23 08:40:48] ppocr DEBUG: rec_res num  : 8, elapsed : 0.0677194595336914
#   -> page_2_line_7.png recognized='guftando mas- de oir, y pregun...' matched='gustando mas de oir, y pregun-...' score=95.08196721311475
# [2025/03/23 08:40:48] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:48] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.049970388412475586
# [2025/03/23 08:40:48] ppocr DEBUG: rec_res num  : 4, elapsed : 0.03195333480834961
#   -> page_2_line_8.png recognized='en la natural ignorancia de lo...' matched='en la natural ignorancia de lo...' score=100.0
# [2025/03/23 08:40:48] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:48] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.015888214111328125
# [2025/03/23 08:40:49] ppocr DEBUG: rec_res num  : 1, elapsed : 0.02081298828125
#   -> page_2_line_9.png recognized='Cant.8.I...' matched='dad....' score=33.333333333333336
# [2025/03/23 08:40:49] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:49] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.057140350341796875
# [2025/03/23 08:40:49] ppocr DEBUG: rec_res num  : 2, elapsed : 0.0639793872833252
#   -> page_3_line_0.png recognized='Exit lnstruccion ae cnristiana...' matched='truccion de Christiana, y Poli...' score=54.42176870748299
# [2025/03/23 08:40:49] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:49] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.04779839515686035
# [2025/03/23 08:40:49] ppocr DEBUG: rec_res num  : 0, elapsed : 2.1457672119140625e-06
# WARNING: No bounding boxes recognized for /content/dataset_with_lines/Buendia - Instruccion/images/lines/page_3_line_1.png
#   -> page_3_line_1.png recognized='...' matched='[NO RECOGNIZED TEXT]...' score=0
# [2025/03/23 08:40:49] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:49] ppocr DEBUG: dt_boxes num : 7, elapsed : 0.06700873374938965
# [2025/03/23 08:40:50] ppocr DEBUG: rec_res num  : 7, elapsed : 0.053772926330566406
#   -> page_3_line_10.png recognized='fenatan culta, y difcreta la V...' matched='seña tan culta, y discreta la ...' score=91.35802469135803
# [2025/03/23 08:40:50] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:50] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.014951944351196289
# [2025/03/23 08:40:50] ppocr DEBUG: rec_res num  : 0, elapsed : 1.9073486328125e-06
# WARNING: No bounding boxes recognized for /content/dataset_with_lines/Buendia - Instruccion/images/lines/page_3_line_11.png
#   -> page_3_line_11.png recognized='...' matched='[NO RECOGNIZED TEXT]...' score=0
# [2025/03/23 08:40:50] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:50] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.02253890037536621
# [2025/03/23 08:40:50] ppocr DEBUG: rec_res num  : 1, elapsed : 0.009094953536987305
#   -> page_3_line_12.png recognized='CENSUH...' matched='NIÑO JESUS....' score=35.29411764705882
# [2025/03/23 08:40:50] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:50] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.014671564102172852
# [2025/03/23 08:40:50] ppocr DEBUG: rec_res num  : 0, elapsed : 1.430511474609375e-06
# WARNING: No bounding boxes recognized for /content/dataset_with_lines/Buendia - Instruccion/images/lines/page_3_line_13.png
#   -> page_3_line_13.png recognized='...' matched='[NO RECOGNIZED TEXT]...' score=0
# [2025/03/23 08:40:50] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:50] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.013562917709350586
# [2025/03/23 08:40:50] ppocr DEBUG: rec_res num  : 0, elapsed : 1.430511474609375e-06
# WARNING: No bounding boxes recognized for /content/dataset_with_lines/Buendia - Instruccion/images/lines/page_3_line_14.png
#   -> page_3_line_14.png recognized='...' matched='[NO RECOGNIZED TEXT]...' score=0
# [2025/03/23 08:40:50] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:50] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.012856245040893555
# [2025/03/23 08:40:50] ppocr DEBUG: rec_res num  : 0, elapsed : 1.6689300537109375e-06
# WARNING: No bounding boxes recognized for /content/dataset_with_lines/Buendia - Instruccion/images/lines/page_3_line_15.png
#   -> page_3_line_15.png recognized='...' matched='[NO RECOGNIZED TEXT]...' score=0
# [2025/03/23 08:40:50] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:50] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.020623445510864258
# [2025/03/23 08:40:50] ppocr DEBUG: rec_res num  : 0, elapsed : 1.1920928955078125e-06
# WARNING: No bounding boxes recognized for /content/dataset_with_lines/Buendia - Instruccion/images/lines/page_3_line_16.png
#   -> page_3_line_16.png recognized='...' matched='[NO RECOGNIZED TEXT]...' score=0
# [2025/03/23 08:40:50] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:50] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.01565861701965332
# [2025/03/23 08:40:50] ppocr DEBUG: rec_res num  : 0, elapsed : 1.1920928955078125e-06
# WARNING: No bounding boxes recognized for /content/dataset_with_lines/Buendia - Instruccion/images/lines/page_3_line_17.png
#   -> page_3_line_17.png recognized='...' matched='[NO RECOGNIZED TEXT]...' score=0
# [2025/03/23 08:40:50] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:50] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.014367103576660156
# [2025/03/23 08:40:50] ppocr DEBUG: rec_res num  : 0, elapsed : 1.1920928955078125e-06
# WARNING: No bounding boxes recognized for /content/dataset_with_lines/Buendia - Instruccion/images/lines/page_3_line_18.png
#   -> page_3_line_18.png recognized='...' matched='[NO RECOGNIZED TEXT]...' score=0
# [2025/03/23 08:40:50] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:50] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.03556966781616211
# [2025/03/23 08:40:50] ppocr DEBUG: rec_res num  : 0, elapsed : 1.6689300537109375e-06
# WARNING: No bounding boxes recognized for /content/dataset_with_lines/Buendia - Instruccion/images/lines/page_3_line_19.png
#   -> page_3_line_19.png recognized='...' matched='[NO RECOGNIZED TEXT]...' score=0
# [2025/03/23 08:40:50] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:50] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.016486644744873047
# [2025/03/23 08:40:50] ppocr DEBUG: rec_res num  : 1, elapsed : 0.008867263793945312
#   -> page_3_line_2.png recognized='X...' matched='no Exemplar de todas las virtu...' score=6.25
# [2025/03/23 08:40:50] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:50] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.014927864074707031
# [2025/03/23 08:40:50] ppocr DEBUG: rec_res num  : 0, elapsed : 9.5367431640625e-07
# WARNING: No bounding boxes recognized for /content/dataset_with_lines/Buendia - Instruccion/images/lines/page_3_line_20.png
#   -> page_3_line_20.png recognized='...' matched='[NO RECOGNIZED TEXT]...' score=0
# [2025/03/23 08:40:50] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:50] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.017967939376831055
# [2025/03/23 08:40:50] ppocr DEBUG: rec_res num  : 0, elapsed : 1.1920928955078125e-06
# WARNING: No bounding boxes recognized for /content/dataset_with_lines/Buendia - Instruccion/images/lines/page_3_line_3.png
#   -> page_3_line_3.png recognized='...' matched='[NO RECOGNIZED TEXT]...' score=0
# [2025/03/23 08:40:50] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:50] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.01468801498413086
# [2025/03/23 08:40:50] ppocr DEBUG: rec_res num  : 0, elapsed : 1.1920928955078125e-06
# WARNING: No bounding boxes recognized for /content/dataset_with_lines/Buendia - Instruccion/images/lines/page_3_line_4.png
#   -> page_3_line_4.png recognized='...' matched='[NO RECOGNIZED TEXT]...' score=0
# [2025/03/23 08:40:50] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:50] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.012776851654052734
# [2025/03/23 08:40:50] ppocr DEBUG: rec_res num  : 0, elapsed : 1.1920928955078125e-06
# WARNING: No bounding boxes recognized for /content/dataset_with_lines/Buendia - Instruccion/images/lines/page_3_line_5.png
#   -> page_3_line_5.png recognized='...' matched='[NO RECOGNIZED TEXT]...' score=0
# [2025/03/23 08:40:50] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:50] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.014298200607299805
# [2025/03/23 08:40:50] ppocr DEBUG: rec_res num  : 0, elapsed : 9.5367431640625e-07
# WARNING: No bounding boxes recognized for /content/dataset_with_lines/Buendia - Instruccion/images/lines/page_3_line_6.png
#   -> page_3_line_6.png recognized='...' matched='[NO RECOGNIZED TEXT]...' score=0
# [2025/03/23 08:40:50] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:50] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.013974189758300781
# [2025/03/23 08:40:50] ppocr DEBUG: rec_res num  : 0, elapsed : 1.1920928955078125e-06
# WARNING: No bounding boxes recognized for /content/dataset_with_lines/Buendia - Instruccion/images/lines/page_3_line_7.png
#   -> page_3_line_7.png recognized='...' matched='[NO RECOGNIZED TEXT]...' score=0
# [2025/03/23 08:40:50] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:50] ppocr DEBUG: dt_boxes num : 9, elapsed : 0.02685379981994629
# [2025/03/23 08:40:51] ppocr DEBUG: rec_res num  : 9, elapsed : 0.05449485778808594
#   -> page_3_line_8.png recognized='Trianza de la Ninez: Afsi fea;...' matched='crianza de la niñez. Assi sea,...' score=80.0
# [2025/03/23 08:40:51] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:51] ppocr DEBUG: dt_boxes num : 14, elapsed : 0.08021330833435059
# [2025/03/23 08:40:52] ppocr DEBUG: rec_res num  : 14, elapsed : 0.09110140800476074
#   -> page_3_line_9.png recognized='cifco de Baftero y de Vilana, ...' matched='o Niño tierno, y Dios Eterno,...' score=45.45454545454546
# [2025/03/23 08:40:52] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:52] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.017455101013183594
# [2025/03/23 08:40:52] ppocr DEBUG: rec_res num  : 2, elapsed : 0.04537463188171387
#   -> page_4_line_0.png recognized='Exit lnstruccion ae cnristiana...' matched='truccion de Christiana, y Poli...' score=54.42176870748299
# [2025/03/23 08:40:52] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:52] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.017418861389160156
# [2025/03/23 08:40:52] ppocr DEBUG: rec_res num  : 0, elapsed : 1.1920928955078125e-06
# WARNING: No bounding boxes recognized for /content/dataset_with_lines/Buendia - Instruccion/images/lines/page_4_line_1.png
#   -> page_4_line_1.png recognized='...' matched='[NO RECOGNIZED TEXT]...' score=0
# [2025/03/23 08:40:52] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:52] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.03154349327087402
# [2025/03/23 08:40:52] ppocr DEBUG: rec_res num  : 0, elapsed : 1.1920928955078125e-06
# WARNING: No bounding boxes recognized for /content/dataset_with_lines/Buendia - Instruccion/images/lines/page_4_line_10.png
#   -> page_4_line_10.png recognized='...' matched='[NO RECOGNIZED TEXT]...' score=0
# [2025/03/23 08:40:52] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:52] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.02207326889038086
# [2025/03/23 08:40:52] ppocr DEBUG: rec_res num  : 0, elapsed : 1.430511474609375e-06
# WARNING: No bounding boxes recognized for /content/dataset_with_lines/Buendia - Instruccion/images/lines/page_4_line_11.png
#   -> page_4_line_11.png recognized='...' matched='[NO RECOGNIZED TEXT]...' score=0
# [2025/03/23 08:40:52] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:52] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.022429466247558594
# [2025/03/23 08:40:52] ppocr DEBUG: rec_res num  : 0, elapsed : 1.1920928955078125e-06
# WARNING: No bounding boxes recognized for /content/dataset_with_lines/Buendia - Instruccion/images/lines/page_4_line_12.png
#   -> page_4_line_12.png recognized='...' matched='[NO RECOGNIZED TEXT]...' score=0
# [2025/03/23 08:40:52] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:52] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.022939682006835938
# [2025/03/23 08:40:52] ppocr DEBUG: rec_res num  : 1, elapsed : 0.009615898132324219
#   -> page_4_line_13.png recognized='About this bookFREE...' matched='lo que deben estudiar. Por est...' score=37.03703703703704
# [2025/03/23 08:40:52] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:52] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.014171123504638672
# [2025/03/23 08:40:52] ppocr DEBUG: rec_res num  : 0, elapsed : 1.430511474609375e-06
# WARNING: No bounding boxes recognized for /content/dataset_with_lines/Buendia - Instruccion/images/lines/page_4_line_2.png
#   -> page_4_line_2.png recognized='...' matched='[NO RECOGNIZED TEXT]...' score=0
# [2025/03/23 08:40:52] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:52] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.026422739028930664
# [2025/03/23 08:40:52] ppocr DEBUG: rec_res num  : 0, elapsed : 1.430511474609375e-06
# WARNING: No bounding boxes recognized for /content/dataset_with_lines/Buendia - Instruccion/images/lines/page_4_line_3.png
#   -> page_4_line_3.png recognized='...' matched='[NO RECOGNIZED TEXT]...' score=0
# [2025/03/23 08:40:52] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:52] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.013668298721313477
# [2025/03/23 08:40:52] ppocr DEBUG: rec_res num  : 0, elapsed : 1.1920928955078125e-06
# WARNING: No bounding boxes recognized for /content/dataset_with_lines/Buendia - Instruccion/images/lines/page_4_line_4.png
#   -> page_4_line_4.png recognized='...' matched='[NO RECOGNIZED TEXT]...' score=0
# [2025/03/23 08:40:52] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:53] ppocr DEBUG: dt_boxes num : 20, elapsed : 0.062139034271240234
# [2025/03/23 08:40:53] ppocr DEBUG: rec_res num  : 20, elapsed : 0.12293767929077148
#   -> page_4_line_5.png recognized=')( X)(...' matched='PDF p1...' score=16.666666666666664
# [2025/03/23 08:40:53] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:53] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.019628524780273438
# [2025/03/23 08:40:54] ppocr DEBUG: rec_res num  : 2, elapsed : 0.023110389709472656
#   -> page_4_line_6.png recognized='M....' matched='dad....' score=33.333333333333336
# [2025/03/23 08:40:54] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:54] ppocr DEBUG: dt_boxes num : 15, elapsed : 0.05803227424621582
# [2025/03/23 08:40:55] ppocr DEBUG: rec_res num  : 15, elapsed : 0.07490897178649902
#   -> page_4_line_7.png recognized='Eorden de V.A.he vifto el Libr...' matched='DE orden del Ilustre Señor Don...' score=45.714285714285715
# [2025/03/23 08:40:55] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:55] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.01787734031677246
# [2025/03/23 08:40:55] ppocr DEBUG: rec_res num  : 3, elapsed : 0.025213241577148438
#   -> page_4_line_8.png recognized='partidas...' matched='dignasteis de llamaros...' score=40.0
# [2025/03/23 08:40:55] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:55] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.014863014221191406
# [2025/03/23 08:40:55] ppocr DEBUG: rec_res num  : 0, elapsed : 1.430511474609375e-06
# WARNING: No bounding boxes recognized for /content/dataset_with_lines/Buendia - Instruccion/images/lines/page_4_line_9.png
#   -> page_4_line_9.png recognized='...' matched='[NO RECOGNIZED TEXT]...' score=0
# [2025/03/23 08:40:55] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:55] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.026616811752319336
# [2025/03/23 08:40:55] ppocr DEBUG: rec_res num  : 2, elapsed : 0.05440473556518555
#   -> page_5_line_0.png recognized='Exit lnstruccion ae cnristiana...' matched='truccion de Christiana, y Poli...' score=54.42176870748299
# [2025/03/23 08:40:55] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:55] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.04172086715698242
# [2025/03/23 08:40:55] ppocr DEBUG: rec_res num  : 0, elapsed : 1.430511474609375e-06
# WARNING: No bounding boxes recognized for /content/dataset_with_lines/Buendia - Instruccion/images/lines/page_5_line_1.png
#   -> page_5_line_1.png recognized='...' matched='[NO RECOGNIZED TEXT]...' score=0
# [2025/03/23 08:40:55] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:55] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.04892373085021973
# [2025/03/23 08:40:55] ppocr DEBUG: rec_res num  : 2, elapsed : 0.060160160064697266
#   -> page_5_line_10.png recognized='Me manus una capit. Y como fer...' matched='mas rendida; y la modestia, y ...' score=47.05882352941176
# [2025/03/23 08:40:55] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:56] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.038134098052978516
# [2025/03/23 08:40:56] ppocr DEBUG: rec_res num  : 5, elapsed : 0.030005455017089844
#   -> page_5_line_11.png recognized='cedad, querer eftimar el valor...' matched='lo que deben estudiar. Por est...' score=50.0
# [2025/03/23 08:40:56] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:56] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.0185396671295166
# [2025/03/23 08:40:56] ppocr DEBUG: rec_res num  : 3, elapsed : 0.027968168258666992
#   -> page_5_line_12.png recognized='colocar entre las joyas de may...' matched='con los Padres en la obedienci...' score=51.42857142857142
# [2025/03/23 08:40:56] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:56] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.01434779167175293
# [2025/03/23 08:40:56] ppocr DEBUG: rec_res num  : 0, elapsed : 1.430511474609375e-06
# WARNING: No bounding boxes recognized for /content/dataset_with_lines/Buendia - Instruccion/images/lines/page_5_line_13.png
#   -> page_5_line_13.png recognized='...' matched='[NO RECOGNIZED TEXT]...' score=0
# [2025/03/23 08:40:56] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:56] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.020914554595947266
# [2025/03/23 08:40:56] ppocr DEBUG: rec_res num  : 0, elapsed : 2.6226043701171875e-06
# WARNING: No bounding boxes recognized for /content/dataset_with_lines/Buendia - Instruccion/images/lines/page_5_line_14.png
#   -> page_5_line_14.png recognized='...' matched='[NO RECOGNIZED TEXT]...' score=0
# [2025/03/23 08:40:56] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:56] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.01791548728942871
# [2025/03/23 08:40:56] ppocr DEBUG: rec_res num  : 0, elapsed : 1.430511474609375e-06
# WARNING: No bounding boxes recognized for /content/dataset_with_lines/Buendia - Instruccion/images/lines/page_5_line_15.png
#   -> page_5_line_15.png recognized='...' matched='[NO RECOGNIZED TEXT]...' score=0
# [2025/03/23 08:40:56] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:56] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.013078927993774414
# [2025/03/23 08:40:56] ppocr DEBUG: rec_res num  : 0, elapsed : 1.6689300537109375e-06
# WARNING: No bounding boxes recognized for /content/dataset_with_lines/Buendia - Instruccion/images/lines/page_5_line_16.png
#   -> page_5_line_16.png recognized='...' matched='[NO RECOGNIZED TEXT]...' score=0
# [2025/03/23 08:40:56] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:56] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.012333869934082031
# [2025/03/23 08:40:56] ppocr DEBUG: rec_res num  : 0, elapsed : 1.1920928955078125e-06
# WARNING: No bounding boxes recognized for /content/dataset_with_lines/Buendia - Instruccion/images/lines/page_5_line_17.png
#   -> page_5_line_17.png recognized='...' matched='[NO RECOGNIZED TEXT]...' score=0
# [2025/03/23 08:40:56] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:56] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.02122354507446289
# [2025/03/23 08:40:56] ppocr DEBUG: rec_res num  : 1, elapsed : 0.020993471145629883
#   -> page_5_line_18.png recognized='About this bookFREE...' matched='lo que deben estudiar. Por est...' score=37.03703703703704
# [2025/03/23 08:40:56] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:56] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.014244794845581055
# [2025/03/23 08:40:56] ppocr DEBUG: rec_res num  : 0, elapsed : 1.6689300537109375e-06
# WARNING: No bounding boxes recognized for /content/dataset_with_lines/Buendia - Instruccion/images/lines/page_5_line_2.png
#   -> page_5_line_2.png recognized='...' matched='[NO RECOGNIZED TEXT]...' score=0
# [2025/03/23 08:40:56] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:56] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.03809762001037598
# [2025/03/23 08:40:56] ppocr DEBUG: rec_res num  : 0, elapsed : 9.5367431640625e-07
# WARNING: No bounding boxes recognized for /content/dataset_with_lines/Buendia - Instruccion/images/lines/page_5_line_3.png
#   -> page_5_line_3.png recognized='...' matched='[NO RECOGNIZED TEXT]...' score=0
# [2025/03/23 08:40:56] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:56] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.03749442100524902
# [2025/03/23 08:40:56] ppocr DEBUG: rec_res num  : 0, elapsed : 7.152557373046875e-07
# WARNING: No bounding boxes recognized for /content/dataset_with_lines/Buendia - Instruccion/images/lines/page_5_line_4.png
#   -> page_5_line_4.png recognized='...' matched='[NO RECOGNIZED TEXT]...' score=0
# [2025/03/23 08:40:56] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:56] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.03364109992980957
# [2025/03/23 08:40:56] ppocr DEBUG: rec_res num  : 0, elapsed : 9.5367431640625e-07
# WARNING: No bounding boxes recognized for /content/dataset_with_lines/Buendia - Instruccion/images/lines/page_5_line_5.png
#   -> page_5_line_5.png recognized='...' matched='[NO RECOGNIZED TEXT]...' score=0
# [2025/03/23 08:40:56] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:56] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.041782379150390625
# [2025/03/23 08:40:56] ppocr DEBUG: rec_res num  : 0, elapsed : 1.1920928955078125e-06
# WARNING: No bounding boxes recognized for /content/dataset_with_lines/Buendia - Instruccion/images/lines/page_5_line_6.png
#   -> page_5_line_6.png recognized='...' matched='[NO RECOGNIZED TEXT]...' score=0
# [2025/03/23 08:40:56] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:57] ppocr DEBUG: dt_boxes num : 31, elapsed : 0.06941103935241699
# [2025/03/23 08:40:58] ppocr DEBUG: rec_res num  : 31, elapsed : 0.20300984382629395
#   -> page_5_line_7.png recognized='hemos de dar en otro mas fever...' matched='no Exemplar de todas las virtu...' score=55.072463768115945
# [2025/03/23 08:40:58] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:59] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.054200172424316406
# [2025/03/23 08:40:59] ppocr DEBUG: rec_res num  : 1, elapsed : 0.09937214851379395
#   -> page_5_line_8.png recognized='familiares, que fe dexan trata...' matched='MADRE, que se porten como sus...' score=50.0
# [2025/03/23 08:40:59] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:59] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.021101951599121094
# [2025/03/23 08:40:59] ppocr DEBUG: rec_res num  : 6, elapsed : 0.03732728958129883
#   -> page_5_line_9.png recognized='horas , companeros infeparable...' matched='y consumados, agradables a...' score=50.0
# [2025/03/23 08:40:59] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:40:59] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.016446352005004883
# ...
# [2025/03/23 08:42:12] ppocr DEBUG: rec_res num  : 0, elapsed : 9.5367431640625e-07
# WARNING: No bounding boxes recognized for /content/dataset_with_lines/Paredes - Reglas generales/images/lines/page_1_line_4.png
#   -> page_1_line_4.png recognized='...' matched='[NO RECOGNIZED TEXT]...' score=0
# [2025/03/23 08:42:12] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:42:12] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.014662027359008789
# [2025/03/23 08:42:12] ppocr DEBUG: rec_res num  : 0, elapsed : 1.1920928955078125e-06
# WARNING: No bounding boxes recognized for /content/dataset_with_lines/Paredes - Reglas generales/images/lines/page_1_line_5.png
#   -> page_1_line_5.png recognized='...' matched='[NO RECOGNIZED TEXT]...' score=0
# [2025/03/23 08:42:12] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:42:12] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.014402627944946289
# [2025/03/23 08:42:12] ppocr DEBUG: rec_res num  : 0, elapsed : 1.430511474609375e-06
# WARNING: No bounding boxes recognized for /content/dataset_with_lines/Paredes - Reglas generales/images/lines/page_1_line_6.png
#   -> page_1_line_6.png recognized='...' matched='[NO RECOGNIZED TEXT]...' score=0
# [2025/03/23 08:42:12] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:42:13] ppocr DEBUG: dt_boxes num : 54, elapsed : 0.05851626396179199
# [2025/03/23 08:42:14] ppocr DEBUG: rec_res num  : 54, elapsed : 0.155656099319458
#   -> page_1_line_7.png recognized='Eftasefian enlugardeverfalilla...' matched='Estas están en lugar de versal...' score=77.61194029850746
# [2025/03/23 08:42:14] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:42:14] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.01479482650756836
# [2025/03/23 08:42:14] ppocr DEBUG: rec_res num  : 0, elapsed : 7.152557373046875e-07
# WARNING: No bounding boxes recognized for /content/dataset_with_lines/Paredes - Reglas generales/images/lines/page_1_line_8.png
#   -> page_1_line_8.png recognized='...' matched='[NO RECOGNIZED TEXT]...' score=0
# [2025/03/23 08:42:14] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:42:14] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.012778759002685547
# [2025/03/23 08:42:14] ppocr DEBUG: rec_res num  : 0, elapsed : 1.1920928955078125e-06
# WARNING: No bounding boxes recognized for /content/dataset_with_lines/Paredes - Reglas generales/images/lines/page_1_line_9.png
#   -> page_1_line_9.png recognized='...' matched='[NO RECOGNIZED TEXT]...' score=0
# [2025/03/23 08:42:14] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:42:14] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.013425350189208984
# [2025/03/23 08:42:14] ppocr DEBUG: rec_res num  : 0, elapsed : 1.1920928955078125e-06
# WARNING: No bounding boxes recognized for /content/dataset_with_lines/Paredes - Reglas generales/images/lines/page_2_line_0.png
#   -> page_2_line_0.png recognized='...' matched='[NO RECOGNIZED TEXT]...' score=0
# [2025/03/23 08:42:14] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:42:14] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.013212919235229492
# [2025/03/23 08:42:14] ppocr DEBUG: rec_res num  : 0, elapsed : 1.1920928955078125e-06
# WARNING: No bounding boxes recognized for /content/dataset_with_lines/Paredes - Reglas generales/images/lines/page_2_line_1.png
#   -> page_2_line_1.png recognized='...' matched='[NO RECOGNIZED TEXT]...' score=0
# [2025/03/23 08:42:14] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:42:14] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.011647701263427734
# [2025/03/23 08:42:14] ppocr DEBUG: rec_res num  : 0, elapsed : 9.5367431640625e-07
# WARNING: No bounding boxes recognized for /content/dataset_with_lines/Paredes - Reglas generales/images/lines/page_2_line_2.png
#   -> page_2_line_2.png recognized='...' matched='[NO RECOGNIZED TEXT]...' score=0
# [2025/03/23 08:42:14] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:42:14] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.011452674865722656
# [2025/03/23 08:42:14] ppocr DEBUG: rec_res num  : 0, elapsed : 1.1920928955078125e-06
# WARNING: No bounding boxes recognized for /content/dataset_with_lines/Paredes - Reglas generales/images/lines/page_3_line_0.png
#   -> page_3_line_0.png recognized='...' matched='[NO RECOGNIZED TEXT]...' score=0
# [2025/03/23 08:42:14] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:42:14] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.012740135192871094
# [2025/03/23 08:42:14] ppocr DEBUG: rec_res num  : 0, elapsed : 9.5367431640625e-07
# WARNING: No bounding boxes recognized for /content/dataset_with_lines/Paredes - Reglas generales/images/lines/page_3_line_1.png
#   -> page_3_line_1.png recognized='...' matched='[NO RECOGNIZED TEXT]...' score=0
# [2025/03/23 08:42:14] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:42:14] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.014981508255004883
# [2025/03/23 08:42:14] ppocr DEBUG: rec_res num  : 3, elapsed : 0.02716064453125
#   -> page_3_line_10.png recognized='nomorts.ytoorenomorespropiosde...' matched='nombres y sobrenombres propios...' score=70.79646017699115
# [2025/03/23 08:42:14] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:42:14] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.01267385482788086
# [2025/03/23 08:42:14] ppocr DEBUG: rec_res num  : 2, elapsed : 0.01989436149597168
#   -> page_3_line_11.png recognized='AlNoayguedezirloareeltaletra,p...' matched='A	No ay que decir sobre esta l...' score=72.89719626168225
# [2025/03/23 08:42:14] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:42:14] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.01260995864868164
# [2025/03/23 08:42:14] ppocr DEBUG: rec_res num  : 2, elapsed : 0.01852893829345703
#   -> page_3_line_12.png recognized='dro devnoaotro,yotros,que ficm...' matched='dro de vno a otro, y otros, qu...' score=79.66101694915254
# [2025/03/23 08:42:14] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:42:14] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.014070749282836914
# [2025/03/23 08:42:14] ppocr DEBUG: rec_res num  : 2, elapsed : 0.01906132698059082
#   -> page_3_line_13.png recognized='B-iEftacscn.lagnetropiecanmuch...' matched='B	Esta es en la que tropiezan ...' score=66.66666666666667
# [2025/03/23 08:42:14] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:42:15] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.019207000732421875
# [2025/03/23 08:42:15] ppocr DEBUG: rec_res num  : 6, elapsed : 0.038889169692993164
#   -> page_3_line_14.png recognized='Dcn con h.vna.yquales con laot...' matched='nen con la vna, y quales con l...' score=81.9672131147541
# [2025/03/23 08:42:15] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:42:15] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.016752958297729492
# [2025/03/23 08:42:15] ppocr DEBUG: rec_res num  : 0, elapsed : 7.152557373046875e-07
# WARNING: No bounding boxes recognized for /content/dataset_with_lines/Paredes - Reglas generales/images/lines/page_3_line_15.png
#   -> page_3_line_15.png recognized='...' matched='[NO RECOGNIZED TEXT]...' score=0
# [2025/03/23 08:42:15] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:42:15] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.011097908020019531
# [2025/03/23 08:42:15] ppocr DEBUG: rec_res num  : 0, elapsed : 1.1920928955078125e-06
# WARNING: No bounding boxes recognized for /content/dataset_with_lines/Paredes - Reglas generales/images/lines/page_3_line_16.png
#   -> page_3_line_16.png recognized='...' matched='[NO RECOGNIZED TEXT]...' score=0
# [2025/03/23 08:42:15] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:42:15] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.014005899429321289
# [2025/03/23 08:42:15] ppocr DEBUG: rec_res num  : 0, elapsed : 7.152557373046875e-07
# WARNING: No bounding boxes recognized for /content/dataset_with_lines/Paredes - Reglas generales/images/lines/page_3_line_2.png
#   -> page_3_line_2.png recognized='...' matched='[NO RECOGNIZED TEXT]...' score=0
# [2025/03/23 08:42:15] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:42:15] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.01189732551574707
# [2025/03/23 08:42:15] ppocr DEBUG: rec_res num  : 0, elapsed : 9.5367431640625e-07
# WARNING: No bounding boxes recognized for /content/dataset_with_lines/Paredes - Reglas generales/images/lines/page_3_line_3.png
#   -> page_3_line_3.png recognized='...' matched='[NO RECOGNIZED TEXT]...' score=0
# [2025/03/23 08:42:15] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:42:15] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.01724696159362793
# [2025/03/23 08:42:15] ppocr DEBUG: rec_res num  : 6, elapsed : 0.04568076133728027
#   -> page_3_line_4.png recognized='inprenta.Cap.ll...' matched='acento grave....' score=35.71428571428571
# [2025/03/23 08:42:15] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:42:16] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.022835969924926758
# [2025/03/23 08:42:16] ppocr DEBUG: rec_res num  : 5, elapsed : 0.04271364212036133
#   -> page_3_line_5.png recognized='querambicn.cnelCaftellanofirve...' matched='que también en el Castellano s...' score=76.92307692307692
# [2025/03/23 08:42:16] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:42:16] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.010812759399414062
# [2025/03/23 08:42:16] ppocr DEBUG: rec_res num  : 1, elapsed : 0.015711545944213867
#   -> page_3_line_6.png recognized='le ytreserra...' matched='te y tres letras....' score=68.96551724137932
# [2025/03/23 08:42:16] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:42:16] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.014055252075195312
# [2025/03/23 08:42:16] ppocr DEBUG: rec_res num  : 0, elapsed : 7.152557373046875e-07
# WARNING: No bounding boxes recognized for /content/dataset_with_lines/Paredes - Reglas generales/images/lines/page_3_line_7.png
#   -> page_3_line_7.png recognized='...' matched='[NO RECOGNIZED TEXT]...' score=0
# [2025/03/23 08:42:16] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:42:16] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.019707679748535156
# [2025/03/23 08:42:16] ppocr DEBUG: rec_res num  : 5, elapsed : 0.04303693771362305
#   -> page_3_line_8.png recognized='Lascincodellasfona,c i,o,u,quc...' matched='Las cinco dellas son a, e, i, ...' score=80.0
# [2025/03/23 08:42:16] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:42:16] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.014724493026733398
# [2025/03/23 08:42:16] ppocr DEBUG: rec_res num  : 3, elapsed : 0.02718210220336914
#   -> page_3_line_9.png recognized='lcrrasmudis,quetonb.c,dg K,p,q...' matched='letras mudas, que son b, c, d,...' score=60.0
# [2025/03/23 08:42:16] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:42:16] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.015942096710205078
# [2025/03/23 08:42:16] ppocr DEBUG: rec_res num  : 0, elapsed : 9.5367431640625e-07
# WARNING: No bounding boxes recognized for /content/dataset_with_lines/Paredes - Reglas generales/images/lines/page_5_line_0.png
#   -> page_5_line_0.png recognized='...' matched='[NO RECOGNIZED TEXT]...' score=0
# [2025/03/23 08:42:16] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:42:17] ppocr DEBUG: dt_boxes num : 10, elapsed : 0.02129817008972168
# [2025/03/23 08:42:17] ppocr DEBUG: rec_res num  : 10, elapsed : 0.07118439674377441
#   -> page_5_line_1.png recognized='delalmprenta.Cap.lll....' matched='la Orthographia es alma della....' score=39.21568627450981
# [2025/03/23 08:42:17] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:42:18] ppocr DEBUG: dt_boxes num : 16, elapsed : 0.06243610382080078
# [2025/03/23 08:42:19] ppocr DEBUG: rec_res num  : 16, elapsed : 0.1181485652923584
#   -> page_5_line_2.png recognized='DoDuplicafeenlalengua Latinadi...' matched='das del Alphabeto Griego, para...' score=41.07142857142857
# [2025/03/23 08:42:19] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:42:19] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.013088464736938477
# [2025/03/23 08:42:19] ppocr DEBUG: rec_res num  : 0, elapsed : 9.5367431640625e-07
# WARNING: No bounding boxes recognized for /content/dataset_with_lines/Paredes - Reglas generales/images/lines/page_5_line_3.png
#   -> page_5_line_3.png recognized='...' matched='[NO RECOGNIZED TEXT]...' score=0
# [2025/03/23 08:42:19] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:42:19] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.01302957534790039
# [2025/03/23 08:42:19] ppocr DEBUG: rec_res num  : 0, elapsed : 9.5367431640625e-07
# WARNING: No bounding boxes recognized for /content/dataset_with_lines/Paredes - Reglas generales/images/lines/page_5_line_4.png
#   -> page_5_line_4.png recognized='...' matched='[NO RECOGNIZED TEXT]...' score=0
# [2025/03/23 08:42:19] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:42:19] ppocr DEBUG: dt_boxes num : 8, elapsed : 0.022824525833129883
# [2025/03/23 08:42:19] ppocr DEBUG: rec_res num  : 8, elapsed : 0.05603384971618652
#   -> page_6_line_0.png recognized='InstilucionrdelArtesk...' matched='CAPITVLO TERCERO....' score=36.8421052631579
# [2025/03/23 08:42:19] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:42:19] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.013978242874145508
# [2025/03/23 08:42:19] ppocr DEBUG: rec_res num  : 0, elapsed : 1.1920928955078125e-06
# WARNING: No bounding boxes recognized for /content/dataset_with_lines/Paredes - Reglas generales/images/lines/page_6_line_1.png
#   -> page_6_line_1.png recognized='...' matched='[NO RECOGNIZED TEXT]...' score=0
# [2025/03/23 08:42:19] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/03/23 08:42:19] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.013508319854736328
# [2025/03/23 08:42:19] ppocr DEBUG: rec_res num  : 0, elapsed : 9.5367431640625e-07
# WARNING: No bounding boxes recognized for /content/dataset_with_lines/Paredes - Reglas generales/images/lines/page_6_line_2.png
#   -> page_6_line_2.png recognized='...' matched='[NO RECOGNIZED TEXT]...' score=0
#
# Line-level .txt generation complete.

# %%
#############################################
# 0. (Optional) Mount Google Drive
#############################################
from google.colab import drive
drive.mount('/content/drive')

#############################################
# 1. Install Dependencies
#############################################
# !sudo apt-get -y install poppler-utils tree
# !pip install paddleocr transformers peft albumentations PyPDF2 jiwer

#############################################
# 2. Imports and Utility Functions
#############################################
import os
import re
import cv2
import torch
import numpy as np
import matplotlib.pyplot as plt

from PIL import Image, ImageDraw, ImageFont

from paddleocr import PaddleOCR
from transformers import (
    TrOCRProcessor,
    VisionEncoderDecoderModel,
    Trainer,
    TrainingArguments,
    TrainerCallback
)
from torch.utils.data import Dataset, random_split, ConcatDataset
import albumentations as A
from albumentations.pytorch import ToTensorV2
from peft import AdaLoraConfig, get_peft_model
import torch.nn.functional as F

import logging
logging.getLogger("ppocr").setLevel(logging.ERROR)

# We'll still use jiwer for computing WER
import jiwer

#############################################
# Custom CER Function (Levenshtein Distance)
#############################################
def levenshtein_distance(s1, s2):
    m, n = len(s1), len(s2)
    dp = list(range(n + 1))
    for i in range(1, m + 1):
        prev = dp[0]
        dp[0] = i
        for j in range(1, n + 1):
            temp = dp[j]
            if s1[i - 1] == s2[j - 1]:
                dp[j] = prev
            else:
                dp[j] = 1 + min(prev, dp[j], dp[j - 1])
            prev = temp
    return dp[n]

def compute_cer_metric(references, hypotheses):
    total_distance = 0
    total_chars = 0
    for ref, hyp in zip(references, hypotheses):
        d = levenshtein_distance(ref, hyp)
        total_distance += d
        total_chars += len(ref)
    return total_distance / total_chars if total_chars > 0 else 0

#############################################
# 3. Utility Functions
#############################################
def normalize_text(text):
    text = text.replace('ç', 'z').replace('ſ', 's')
    text = re.sub(r'[ùúûüū]', 'u', text)
    text = re.sub(r'[àáâãā]', 'a', text)
    text = re.sub(r'(?<![n])́', '', text)
    text = re.sub(r'[̀̀̈]', '', text)
    return text.lower()[:512]

def read_line_text(txt_path):
    with open(txt_path, "r", encoding="utf-8") as f:
        return f.read().strip()

def advanced_preprocess(image):
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    _, bw = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
    denoised = cv2.fastNlMeansDenoising(bw, None, h=30, templateWindowSize=7, searchWindowSize=21)
    coords = np.column_stack(np.where(denoised > 0))
    if coords.size == 0:
        return image
    angle = cv2.minAreaRect(coords)[-1]
    angle = -(90 + angle) if angle < -45 else -angle
    (h, w) = denoised.shape[:2]
    center = (w // 2, h // 2)
    M = cv2.getRotationMatrix2D(center, angle, 1.0)
    deskewed = cv2.warpAffine(denoised, M, (w, h), flags=cv2.INTER_CUBIC, borderMode=cv2.BORDER_REPLICATE)
    return cv2.cvtColor(deskewed, cv2.COLOR_GRAY2RGB)

#############################################
# 4. Define Line-Level Dataset with Augmentation
#############################################
class LineLevelDataset(Dataset):
    def __init__(self, lines_root, processor, synthetic_prob=0.0):
        self.lines_root = lines_root
        self.processor = processor
        self.synthetic_prob = synthetic_prob
        self.samples = []
        for file_name in sorted(os.listdir(self.lines_root)):
            if file_name.lower().endswith((".png", ".jpg", ".jpeg")):
                base_name = file_name.rsplit(".", 1)[0]
                txt_name = base_name + ".txt"
                txt_path = os.path.join(self.lines_root, txt_name)
                if os.path.exists(txt_path):
                    self.samples.append((file_name, txt_name))
        # Moderate augmentation pipeline
        self.transform = A.Compose([
            A.Resize(height=384, width=384, always_apply=True),
            A.OneOf([
                A.GaussianBlur(blur_limit=(3, 7), p=0.3),
                A.MedianBlur(blur_limit=3, p=0.3)
            ], p=0.3),
            A.RandomBrightnessContrast(p=0.3),
            A.Rotate(limit=3, p=0.4),
            A.Perspective(scale=(0.02, 0.05), keep_size=True, p=0.2),
            A.ElasticTransform(alpha=1, sigma=50, alpha_affine=50, p=0.1),
            A.CoarseDropout(max_holes=8, max_height=16, max_width=16, p=0.1),
            A.ShiftScaleRotate(shift_limit=0.02, scale_limit=0.02, rotate_limit=3, p=0.3),
            ToTensorV2()
        ])

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        img_file, txt_file = self.samples[idx]
        line_img_path = os.path.join(self.lines_root, img_file)
        line_txt_path = os.path.join(self.lines_root, txt_file)
        text = read_line_text(line_txt_path)
        # Use real image (optionally, you can apply advanced_preprocess)
        img = cv2.imread(line_img_path, cv2.IMREAD_COLOR)
        if img is None:
            raise ValueError(f"Unable to load line image: {line_img_path}")
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        pil_img = Image.fromarray(img)
        aug = self.transform(image=np.array(pil_img))['image']
        aug_np = aug.permute(1, 2, 0).mul(255).byte().numpy()
        pil_img = Image.fromarray(aug_np)
        pixel_values = self.processor(pil_img, return_tensors="pt").pixel_values.squeeze(0)
        text_encoding = self.processor.tokenizer(
            text, return_tensors="pt", padding="max_length", truncation=True, max_length=128
        )
        labels = text_encoding["input_ids"][0]
        return {"pixel_values": pixel_values, "labels": labels}

#############################################
# 5. Gather All Line Folders from Dataset Root
#############################################
def gather_all_line_folders(dataset_root):
    lines_paths = []
    for folder_name in sorted(os.listdir(dataset_root)):
        folder_path = os.path.join(dataset_root, folder_name)
        if not os.path.isdir(folder_path):
            continue
        images_folder = os.path.join(folder_path, "images")
        lines_folder = os.path.join(images_folder, "lines")
        if os.path.exists(lines_folder):
            lines_paths.append(lines_folder)
    return lines_paths

#############################################
# 6. EMA Callback for Improved Generalization
#############################################
class EMACallback(TrainerCallback):
    def __init__(self, decay=0.999):
        self.decay = decay
        self.ema_weights = {}

    def on_train_begin(self, args, state, control, model=None, **kwargs):
        # Initialize EMA weights
        for name, param in model.named_parameters():
            if param.requires_grad:
                self.ema_weights[name] = param.data.clone()
        return control

    def on_step_end(self, args, state, control, model=None, **kwargs):
        # Update EMA weights after each step
        for name, param in model.named_parameters():
            if param.requires_grad:
                self.ema_weights[name].mul_(self.decay).add_(param.data, alpha=1 - self.decay)
        return control

    def on_evaluate(self, args, state, control, model=None, **kwargs):
        # Backup current weights and use EMA weights for evaluation
        backup = {}
        for name, param in model.named_parameters():
            if param.requires_grad:
                backup[name] = param.data.clone()
                param.data.copy_(self.ema_weights[name])
        control.ema_backup = backup
        return control

    def on_evaluate_end(self, args, state, control, model=None, **kwargs):
        # Restore original weights after evaluation
        if hasattr(control, "ema_backup"):
            for name, param in model.named_parameters():
                if param.requires_grad and name in control.ema_backup:
                    param.data.copy_(control.ema_backup[name])
            del control.ema_backup
        return control

#############################################
# 7. Training Function with Generalization Techniques
#############################################
def train_line_level_model(dataset_root):
    line_folders = gather_all_line_folders(dataset_root)
    if not line_folders:
        print("No line folders found, exiting.")
        return
    processor = TrOCRProcessor.from_pretrained("qantev/trocr-base-spanish", do_resize=False, do_normalize=False)
    line_datasets = [LineLevelDataset(lf, processor, synthetic_prob=0.0) for lf in line_folders]
    full_line_dataset = ConcatDataset(line_datasets)
    print(f"Total line images loaded: {len(full_line_dataset)}")
    train_size = int(0.9 * len(full_line_dataset))
    eval_size = len(full_line_dataset) - train_size
    train_dataset, eval_dataset = random_split(full_line_dataset, [train_size, eval_size])
    print(f"Training samples: {len(train_dataset)}; Evaluation samples: {len(eval_dataset)}")

    # Fine-tune the full model (do not freeze encoder)
    model = VisionEncoderDecoderModel.from_pretrained("qantev/trocr-base-spanish")
    model.config.num_beams = 5
    model.config.early_stopping = True

    # Set up AdaLoRA on the decoder (to keep training lightweight)
    target_modules_list = []
    for name, module in model.decoder.named_modules():
        if ("self_attn.q_proj" in name) or ("self_attn.k_proj" in name) or ("self_attn.v_proj" in name):
            target_modules_list.append(name)
    if not target_modules_list:
        raise AttributeError("No target modules found for AdaLoRA in the decoder.")
    peft_config = AdaLoraConfig(
        target_modules=target_modules_list, init_r=12, lora_alpha=32, lora_dropout=0.1, bias="none"
    )
    model.decoder = get_peft_model(model.decoder, peft_config)

    def print_trainable_parameters(m):
        trainable = sum(p.numel() for p in m.parameters() if p.requires_grad)
        total = sum(p.numel() for p in m.parameters())
        print(f"Trainable parameters: {trainable} / Total parameters: {total}")
    print_trainable_parameters(model)

    training_args = TrainingArguments(
        output_dir="./linelevel_trocr",
        per_device_train_batch_size=4,
        per_device_eval_batch_size=4,
        num_train_epochs=30,
        learning_rate=5e-5,
        fp16=True,
        evaluation_strategy="epoch",
        save_strategy="epoch",
        logging_dir='./logs_line',
        logging_steps=50,
        report_to="none",
        dataloader_drop_last=False,
        remove_unused_columns=True,
        label_smoothing_factor=0.1,
        lr_scheduler_type="cosine",
        warmup_steps=500,
        weight_decay=0.01,
        gradient_accumulation_steps=2,
        max_grad_norm=1.0  # Gradient clipping to stabilize training
    )

    def compute_metrics(eval_pred):
        logits, labels = eval_pred
        if isinstance(logits, (tuple, list)):
            logits = logits[0]
        pred_ids = np.argmax(logits, axis=-1)
        preds = processor.tokenizer.batch_decode(pred_ids, skip_special_tokens=True)
        labels = np.where(labels != -100, labels, processor.tokenizer.pad_token_id)
        refs = processor.tokenizer.batch_decode(labels, skip_special_tokens=True)
        preds = [normalize_text(s) for s in preds]
        refs = [normalize_text(s) for s in refs]
        cer = compute_cer_metric(refs, preds)
        wer = jiwer.wer(refs, preds)
        return {"cer": cer, "wer": wer}

    def collate_fn(batch):
        max_height = max(item["pixel_values"].shape[1] for item in batch)
        max_width = max(item["pixel_values"].shape[2] for item in batch)
        padded_pixel_values = []
        for item in batch:
            pv = item["pixel_values"]
            c, h, w = pv.shape
            padded = torch.zeros((c, max_height, max_width), dtype=pv.dtype)
            padded[:, :h, :w] = pv
            padded_pixel_values.append(padded)
        collated_labels = torch.stack([item["labels"] for item in batch])
        return {"pixel_values": torch.stack(padded_pixel_values), "labels": collated_labels}

    from transformers import Trainer
    class CustomTrainer(Trainer):
        def compute_loss(self, model, inputs, return_outputs=False, **kwargs):
            labels = inputs.pop("labels")
            pixel_values = inputs.pop("pixel_values")
            outputs = model(pixel_values=pixel_values, labels=labels)
            logits = outputs.logits
            vocab_size = logits.size(-1)
            logits = logits.view(-1, vocab_size)
            labels = labels.view(-1)
            valid_mask = labels != -100
            logits = logits[valid_mask]
            labels = labels[valid_mask]
            loss = F.cross_entropy(logits, labels)
            return (loss, outputs) if return_outputs else loss

    # Use EMA callback for better generalization
    ema_callback = EMACallback(decay=0.999)

    trainer = CustomTrainer(
        model=model,
        args=training_args,
        train_dataset=train_dataset,
        eval_dataset=eval_dataset,
        data_collator=collate_fn,
        compute_metrics=compute_metrics,
        callbacks=[ema_callback]
    )

    print("Starting line-level training...")
    trainer.train()
    torch.cuda.empty_cache()
    model.save_pretrained("./final_linelevel_model")
    processor.save_pretrained("./final_linelevel_model")
    print("Training complete. Final model saved to './final_linelevel_model'.")

#############################################
# 8. Putting It All Together
#############################################
def main():
    dataset_root = "/content/dataset_with_lines"  # Update this to your dataset root
    train_line_level_model(dataset_root)

if __name__ == "__main__":
    main()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tree is already the newest version (2.0.2-1).
# poppler-utils is already the newest version (22.02.0-2ubuntu0.6).
# 0 upgraded, 0 newly installed, 0 to remove and 29 not upgraded.
# Requirement already satisfied: paddleocr in /usr/local/lib/python3.11/dist-packages (2.10.0)
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.49.0)
# Requirement already satisfied: peft in /usr/local/lib/python3.11/dist-packages (0.14.0)
# Requirement already satisfied: albumentations in /usr/local/lib/python3.11/dist-packages (2.0.5)
# Requirement already satisfied: PyPDF2 in /usr/local/lib/python3.11/dist-packages (3.0.1)
# Collecting jiwer
#   Downloading jiwer-3.1.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: shapely in /usr/local/lib/python3.11/dist-packages (from paddleocr) (2.0.7)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.11/dist-packages (from paddleocr) (0.25.2)
# Requirement already satisfied: pyclipper in /usr/local/lib/python3.11/dist-packages (from paddleocr) (1.3.0.post6)
# Requirement already satisfied: lmdb in /usr/local/lib/python3.11/dist-packages (from paddleocr) (1.6.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from paddleocr) (4.67.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from paddleocr) (2.0.2)
# Requirement already satisfied: rapidfuzz in /usr/local/lib/python3.11/dist-packages (from paddleocr) (3.12.2)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (from paddleocr) (4.11.0.86)
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.11/dist-packages (from paddleocr) (4.11.0.86)
# Requirement already satisfied: cython in /usr/local/lib/python3.11/dist-packages (from paddleocr) (3.0.12)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from paddleocr) (11.1.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from paddleocr) (6.0.2)
# Requirement already satisfied: python-docx in /usr/local/lib/python3.11/dist-packages (from paddleocr) (1.1.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from paddleocr) (4.13.3)
# Requirement already satisfied: fonttools>=4.24.0 in /usr/local/lib/python3.11/dist-packages (from paddleocr) (4.56.0)
# Requirement already satisfied: fire>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from paddleocr) (0.7.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from paddleocr) (2.32.3)
# Requirement already satisfied: albucore in /usr/local/lib/python3.11/dist-packages (from paddleocr) (0.0.23)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.26.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.29.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from peft) (5.9.5)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.11/dist-packages (from peft) (2.6.0+cu124)
# Requirement already satisfied: accelerate>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from peft) (1.5.2)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.11/dist-packages (from albumentations) (1.14.1)
# Requirement already satisfied: pydantic>=2.9.2 in /usr/local/lib/python3.11/dist-packages (from albumentations) (2.10.6)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in /usr/local/lib/python3.11/dist-packages (from albumentations) (4.11.0.86)
# Requirement already satisfied: stringzilla>=3.10.4 in /usr/local/lib/python3.11/dist-packages (from albucore->paddleocr) (3.12.3)
# Requirement already satisfied: simsimd>=5.9.2 in /usr/local/lib/python3.11/dist-packages (from albucore->paddleocr) (6.2.1)
# Requirement already satisfied: click>=8.1.8 in /usr/local/lib/python3.11/dist-packages (from jiwer) (8.1.8)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.11/dist-packages (from fire>=0.3.0->paddleocr) (2.5.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.26.0->transformers) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.26.0->transformers) (4.12.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.9.2->albumentations) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.9.2->albumentations) (2.27.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.13.0->peft)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.13.0->peft)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.13.0->peft)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.13.0->peft)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.13.0->peft)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.13.0->peft)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.13.0->peft)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.13.0->peft)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.13.0->peft)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.13.0->peft)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.13.0->peft) (1.3.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->paddleocr) (2.6)
# Requirement already satisfied: lxml>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from python-docx->paddleocr) (5.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->paddleocr) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->paddleocr) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->paddleocr) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->paddleocr) (2025.1.31)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.11/dist-packages (from scikit-image->paddleocr) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.11/dist-packages (from scikit-image->paddleocr) (2025.3.13)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image->paddleocr) (0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.13.0->peft) (3.0.2)
# Downloading jiwer-3.1.0-py3-none-any.whl (22 kB)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 66.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 31.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 46.5 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.6 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 1.7 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 14.2 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.9 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.8 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 93.0 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, jiwer, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed jiwer-3.1.0 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127
# preprocessor_config.json:   0%|          | 0.00/364 [00:00<?, ?B/s]
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.48, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# tokenizer_config.json:   0%|          | 0.00/1.38k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.11M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/957 [00:00<?, ?B/s]
# Total line images loaded: 736
# Training samples: 662; Evaluation samples: 74
# config.json:   0%|          | 0.00/4.93k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.54G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.54G [00:00<?, ?B/s]
# Config of the encoder: <class 'transformers.models.vit.modeling_vit.ViTModel'> is overwritten by shared encoder config: ViTConfig {
#   "attention_probs_dropout_prob": 0.0,
#   "encoder_stride": 16,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.0,
#   "hidden_size": 768,
#   "image_size": 384,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "model_type": "vit",
#   "num_attention_heads": 12,
#   "num_channels": 3,
#   "num_hidden_layers": 12,
#   "patch_size": 16,
#   "qkv_bias": false,
#   "torch_dtype": "float32",
#   "transformers_version": "4.49.0"
# }
#
# Config of the decoder: <class 'transformers.models.trocr.modeling_trocr.TrOCRForCausalLM'> is overwritten by shared decoder config: TrOCRConfig {
#   "activation_dropout": 0.0,
#   "activation_function": "relu",
#   "add_cross_attention": true,
#   "attention_dropout": 0.0,
#   "bos_token_id": 0,
#   "classifier_dropout": 0.0,
#   "cross_attention_hidden_size": 768,
#   "d_model": 1024,
#   "decoder_attention_heads": 16,
#   "decoder_ffn_dim": 4096,
#   "decoder_layerdrop": 0.0,
#   "decoder_layers": 12,
#   "decoder_start_token_id": 2,
#   "dropout": 0.1,
#   "eos_token_id": 2,
#   "init_std": 0.02,
#   "is_decoder": true,
#   "layernorm_embedding": false,
#   "max_position_embeddings": 1024,
#   "model_type": "trocr",
#   "pad_token_id": 1,
#   "scale_embedding": true,
#   "tie_word_embeddings": false,
#   "torch_dtype": "float32",
#   "transformers_version": "4.49.0",
#   "use_cache": false,
#   "use_learned_position_embeddings": false,
#   "vocab_size": 50265
# }
# generation_config.json:   0%|          | 0.00/384 [00:00<?, ?B/s]
# Trainable parameters: 87538608 / Total parameters: 385749972
# Starting line-level training...
#     <div>
#
#       <progress value='2490' max='2490' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2490/2490 55:52, Epoch 30/30]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Cer</th>
#       <th>Wer</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>25.742300</td>
#       <td>0.520738</td>
#       <td>0.836028</td>
#       <td>1.006734</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.402200</td>
#       <td>0.228227</td>
#       <td>0.371824</td>
#       <td>0.616162</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>7.456800</td>
#       <td>0.223810</td>
#       <td>0.386836</td>
#       <td>0.612795</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>4.335400</td>
#       <td>0.204765</td>
#       <td>0.354503</td>
#       <td>0.562290</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.769900</td>
#       <td>0.202513</td>
#       <td>0.356813</td>
#       <td>0.558923</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>2.193200</td>
#       <td>0.202339</td>
#       <td>0.359700</td>
#       <td>0.582492</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.965100</td>
#       <td>0.188201</td>
#       <td>0.364319</td>
#       <td>0.528620</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.683500</td>
#       <td>0.201656</td>
#       <td>0.359700</td>
#       <td>0.579125</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.947900</td>
#       <td>0.203024</td>
#       <td>0.368360</td>
#       <td>0.585859</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.776000</td>
#       <td>0.194310</td>
#       <td>0.360277</td>
#       <td>0.552189</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.657100</td>
#       <td>0.201142</td>
#       <td>0.359700</td>
#       <td>0.555556</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.732700</td>
#       <td>0.191035</td>
#       <td>0.349885</td>
#       <td>0.542088</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.642100</td>
#       <td>0.190795</td>
#       <td>0.359122</td>
#       <td>0.528620</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.583800</td>
#       <td>0.190373</td>
#       <td>0.352771</td>
#       <td>0.511785</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.678000</td>
#       <td>0.195084</td>
#       <td>0.360277</td>
#       <td>0.548822</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.642200</td>
#       <td>0.192164</td>
#       <td>0.364896</td>
#       <td>0.569024</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.587600</td>
#       <td>0.189666</td>
#       <td>0.337760</td>
#       <td>0.569024</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.562900</td>
#       <td>0.187127</td>
#       <td>0.360855</td>
#       <td>0.538721</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.619300</td>
#       <td>0.187941</td>
#       <td>0.361432</td>
#       <td>0.528620</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.607100</td>
#       <td>0.187720</td>
#       <td>0.360855</td>
#       <td>0.535354</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.583800</td>
#       <td>0.189623</td>
#       <td>0.357390</td>
#       <td>0.548822</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.608400</td>
#       <td>0.188349</td>
#       <td>0.354503</td>
#       <td>0.555556</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.560000</td>
#       <td>0.191309</td>
#       <td>0.360855</td>
#       <td>0.552189</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.617500</td>
#       <td>0.188844</td>
#       <td>0.349885</td>
#       <td>0.542088</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.550200</td>
#       <td>0.190311</td>
#       <td>0.351039</td>
#       <td>0.552189</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.567300</td>
#       <td>0.190084</td>
#       <td>0.355081</td>
#       <td>0.538721</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.571700</td>
#       <td>0.190591</td>
#       <td>0.358545</td>
#       <td>0.538721</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.630200</td>
#       <td>0.192638</td>
#       <td>0.356236</td>
#       <td>0.548822</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.601200</td>
#       <td>0.194681</td>
#       <td>0.355081</td>
#       <td>0.545455</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.573500</td>
#       <td>0.197377</td>
#       <td>0.355081</td>
#       <td>0.538721</td>
#     </tr>
#   </tbody>
# </table><p>
# ---------------------------------------------------------------------------
# SafetensorError                           Traceback (most recent call last)
# <ipython-input-11-b7abb0ea57c0> in <cell line: 0>()
#     345
#     346 if __name__ == "__main__":
# --> 347     main()
#
# <ipython-input-11-b7abb0ea57c0> in main()
#     342 def main():
#     343     dataset_root = "/content/dataset_with_lines"  # Update this to your dataset root
# --> 344     train_line_level_model(dataset_root)
#     345
#     346 if __name__ == "__main__":
#
# <ipython-input-11-b7abb0ea57c0> in train_line_level_model(dataset_root)
#     333     trainer.train()
#     334     torch.cuda.empty_cache()
# --> 335     model.save_pretrained("./final_linelevel_model")
#     336     processor.save_pretrained("./final_linelevel_model")
#     337     print("Training complete. Final model saved to './final_linelevel_model'.")
#
# /usr/local/lib/python3.11/dist-packages/transformers/modeling_utils.py in save_pretrained(self, save_directory, is_main_process, state_dict, save_function, push_to_hub, max_shard_size, safe_serialization, variant, token, save_peft_format, **kwargs)
#    3030                 # At some point we will need to deal better with save_function (used for TPU and other distributed
#    3031                 # joyfulness), but for now this enough.
# -> 3032                 safe_save_file(shard, os.path.join(save_directory, shard_file), metadata={"format": "pt"})
#    3033             else:
#    3034                 save_function(shard, os.path.join(save_directory, shard_file))
#
# /usr/local/lib/python3.11/dist-packages/safetensors/torch.py in save_file(tensors, filename, metadata)
#     284     ```
#     285     """
# --> 286     serialize_file(_flatten(tensors), filename, metadata=metadata)
#     287
#     288
#
# SafetensorError: Error while serializing: IoError(Os { code: 28, kind: StorageFull, message: "No space left on device" })

# %%
from google.colab import drive
drive.mount('/content/drive')
